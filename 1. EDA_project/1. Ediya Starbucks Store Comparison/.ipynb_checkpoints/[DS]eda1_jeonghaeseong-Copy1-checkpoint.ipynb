# %% [markdown]
# # Ediya Starbucks Store Comparison
# - 프로젝트 개요
#
# ```
#   - 이디야 커피는 가끔 스타벅스 커피 매장에 위치하는 곳에 매장을 위치시키는 것 아니냐는 의심을 받고 있다. 이를 확인해보는 프로젝트를 진행할 것이다.
#
#   - 가까이 위치시킨다의 기준을 번화가 한 블럭 기준으로 주위에 위치하면 가깝다고 판단할 것이다.
# ```
#
# - 목표
#
# ```
#   - 1. 서울시의 스타벅스 매장의 이름과 주소, 구 이름을 pandas data frame으로 정리
#
#   - 2. 서울시의 이디야 매장의 이름과 주소, 구 이름을 pandas data frame으로 정리
#
#   - 3. 위의 결과를 가지고 이디야의 매장이 스타벅스 매장 근처에 있는지를 분석하자.
# ```

# %% [markdown]
# ---

# %% [markdown]
# # 1. 서울시의 스타벅스 매장의 이름과 주소, 구 이름을 pandas data frame으로 정리

# %% [markdown]
# ## 1 - 1. 스타벅스 홈페이지 셀레니움 작업

# %%
# 셀레니움에서 웹드라이버 기능을 쓰겠다.
import time
from selenium.webdriver import ActionChains
from selenium.webdriver.common.by import By
from selenium import webdriver

# 웹드라이버 방법중 크롬을 쓰겠다. 크롬 드라이버를 넣어주겠다.
driver = webdriver.Chrome(executable_path="../driver/chromedriver.exe") # 경로, 권한 설정 잘해줘야
action = ActionChains(driver)
driver.get("https://www.starbucks.co.kr/index.do")
time.sleep(3)

# 화면 최대 크기 설정 - 전체화면
driver.maximize_window()

# %%
# STORE 위치에 마우스 올려놓기

store_tag = driver.find_element(By.CSS_SELECTOR,'#gnb > div > nav > div > ul > li.gnb_nav03 > h2 > a')
action.move_to_element(store_tag).perform()

# %%
# 매장찾기에서 지역검색을 누르기

search_loc = driver.find_element(By.CSS_SELECTOR,'#gnb > div > nav > div > ul > li.gnb_nav03 > div > div > div > ul:nth-child(1) > li:nth-child(3) > a')
action.click(search_loc).perform()
time.sleep(2)

# %%
# 매장찾기에서 지역검색을 누르기 -> 서울 클릭하기. 이땐 액션 쓰면 안됨!

seoul_btn = driver.find_element(By.CSS_SELECTOR,'#container > div > form > fieldset > div > section > article.find_store_cont > article > article:nth-child(4) > div.loca_step1 > div.loca_step1_cont > ul > li:nth-child(1) > a')
seoul_btn.click()
time.sleep(3)

# %%
# 서울 -> 전체 클릭

seoul_total_btn = driver.find_element(By.CSS_SELECTOR,'#mCSB_2_container > ul > li:nth-child(1) > a')
seoul_total_btn.click()
time.sleep(3)

# %% [markdown]
# ---

# %% [markdown]
# ## 1 - 2. html 불러와서 Beautifulsoup 작업

# %%
# 현재 화면의 html 코드를 가져와서 뷰숲으로 작업하기

from bs4 import BeautifulSoup

req = driver.page_source
soup = BeautifulSoup(req, 'html.parser')

# %%
## 서울 전제 리스트 태그 선택

seoul_totalstore_list = soup.select('.quickSearchResultBoxSidoGugun > .quickResultLstCon')
len(seoul_totalstore_list)
# Out:
# 601

# %%
## 데이터 하나만 추출하는 방법

sample_name = sample_name = seoul_totalstore_list[0]['data-name']

sample_addr = seoul_totalstore_list[0].select_one('.result_details').text

print(sample_name)
print(sample_addr)
# Out:
# 역삼아레나빌딩
# 서울특별시 강남구 언주로 425 (역삼동)1522-3232

# %%
## 서울 전제 리스트 태그에서 하나 예시로 정보 추출하기

# 매장 이름
sample_name = seoul_totalstore_list[0]['data-name']

# 매장 위도 lat
sample_lat = seoul_totalstore_list[0]['data-lat']

# 매장 경도 lng
sample_lng = seoul_totalstore_list[0]['data-long']

# 매장 주소
sample_addr = seoul_totalstore_list[0].select_one('.result_details').text.split(")")[0]+')'


print(sample_name)
print(sample_lat)
print(sample_lng)
print(sample_addr)
# Out:
# 역삼아레나빌딩
# 37.501087
# 127.043069
# 서울특별시 강남구 언주로 425 (역삼동)

# %%
## 반복문으로 데이터 합치기 3개만

store_names = []
store_lats = []
store_lngs = []
store_addrs = []


for n in range(3):
    
    store_names.append(seoul_totalstore_list[n]['data-name'])

    # 매장 위도 lat
    store_lats.append(seoul_totalstore_list[n]['data-lat'])

    # 매장 경도 lng
    store_lngs.append(seoul_totalstore_list[n]['data-long'])

    # 매장 주소
    store_addrs.append(seoul_totalstore_list[n].select_one('.result_details').text.split(")")[0]+')')


print(store_names)
print(store_lats)
print(store_lngs)
print(store_addrs)
# Out:
# ['역삼아레나빌딩', '논현역사거리', '신사역성일빌딩']
# ['37.501087', '37.510178', '37.5139309']
# ['127.043069', '127.022223', '127.0206057']
# ['서울특별시 강남구 언주로 425 (역삼동)', '서울특별시 강남구 강남대로 538 (논현동)', '서울특별시 강남구 강남대로 584 (논현동)']

# %%
## 반복문으로 데이터 합치기 전체 (601개)

SB_store_names = []
SB_store_lats = []
SB_store_lngs = []
SB_store_addrs = []


for stores in seoul_totalstore_list:
    
    SB_store_names.append(stores['data-name'])

    # 매장 위도 lat
    SB_store_lats.append(stores['data-lat'])

    # 매장 경도 lng
    SB_store_lngs.append(stores['data-long'])

    # 매장 주소
    SB_store_addrs.append(stores.select_one('.result_details').text.split(")")[0]+')')

# %%
# 데이터 확인하기 1

len(SB_store_names),len(SB_store_lats),len(SB_store_lngs), len(SB_store_addrs)
# Out:
# (601, 601, 601, 601)

# %%
# 데이터 확인하기 2

SB_store_lats
# Out:
# ['37.501087',
#  '37.510178',
#  '37.5139309',
#  '37.499517',
#  '37.494668',
#  '37.515000',
#  '37.5227934',
#  '37.510150',
#  '37.507750',
#  '37.5273669',
#  '37.488008',
#  '37.485192',
#  '37.505321',
#  '37.511293',
#  '37.502117',
#  '37.50999',
#  '37.518181',
#  '37.492805',
#  '37.497711',
#  '37.498973',
#  '37.522156',
#  '37.526283',
#  '37.521933',
#  '37.525216',
#  '37.492396',
#  '37.52236449999999',
#  '37.503331',
#  '37.5075307',
#  '37.5191632',
#  '37.5162021',
#  '37.492167',
#  '37.514887',
#  '37.5236351',
#  '37.496801',
#  '37.4941059',
#  '37.513715',
#  '37.5231593',
#  '37.501623',
#  '37.499721',
#  '37.50314',
#  '37.5243631',
#  '37.5097863',
#  '37.507794',
#  '37.51464884',
#  '37.49966175',
#  '37.490298',
#  '37.50703529',
#  '37.50377562',
#  '37.52674095',
#  '37.52680046',
#  '37.49592355',
#  '37.50236693',
#  '37.5165849',
#  '37.493554',
#  '37.47781106',
#  '37.49971982',
#  '37.49803646',
#  '37.51075489999999',
#  '37.51354184',
#  '37.5018592',
#  '37.52405601',
#  '37.50393894',
#  '37.591531',
#  '37.5953464',
#  '37.5767228',
#  '37.590784',
#  '37.59575188',
#  '37.562337',
#  '37.5928812',
#  '37.5796141021494',
#  '37.57945',
#  '37.542075',
#  '37.5479939',
#  '37.546432',
#  '37.567644',
#  '37.543193',
#  '37.565169',
#  '37.5627541',
#  '37.55726984',
#  '37.56175811',
#  '37.5549672',
#  '37.5605427226347',
#  '37.5444620830457',
#  '37.5430298',
#  '37.547326',
#  '37.539305',
#  '37.555165',
#  '37.534273',
#  '37.537131',
#  '37.527586',
#  '37.518605',
#  '37.528702',
#  '37.523818',
#  '37.542831',
#  '37.53485',
#  '37.551102',
#  '37.551752',
#  '37.533394',
#  '37.54460479',
#  '37.5289857',
#  '37.544118',
#  '37.5288539',
#  '37.52111',
#  '37.54474797',
#  '37.5258562',
#  '37.53854',
#  '37.55415699928705',
#  '37.538571',
#  '37.55126',
#  '37.53286105987034',
#  '37.597842',
#  '37.5930326',
#  '37.60538908',
#  '37.579594',
#  '37.59689',
#  '37.615368',
#  '37.6066536267232',
#  '37.60170912407773']

# %% [markdown]
# ---

# %% [markdown]
# ## 1 - 3. 추출한 데이터 데이터프레임으로 만들기

# %%
## 셀레니움 닫기
driver.quit()

# %%
import pandas as pd
import numpy as np

# %%
SB_stores = pd.DataFrame(zip(SB_store_names, SB_store_lats, SB_store_lngs, SB_store_addrs))
SB_stores
# Out:
#            0                  1                   2  \
# 0    역삼아레나빌딩          37.501087          127.043069
# 1     논현역사거리          37.510178          127.022223
# 2    신사역성일빌딩         37.5139309         127.0206057
# 3     국기원사거리          37.499517          127.031495
# 4    대치재경빌딩R          37.494668          127.062583
# ..       ...                ...                 ...
# 596     사가정역          37.579594          127.087966
# 597      상봉역           37.59689           127.08647
# 598       묵동          37.615368          127.076633
# 599      양원역   37.6066536267232    127.106359790053
# 600      중화역  37.60170912407773  127.07841136432036
#
#                                       3
# 0               서울특별시 강남구 언주로 425 (역삼동)
# 1              서울특별시 강남구 강남대로 538 (논현동)
# 2              서울특별시 강남구 강남대로 584 (논현동)
# 3              서울특별시 강남구 테헤란로 125 (역삼동)
# 4            서울특별시 강남구 남부순환로 2947 (대치동)
# ..                                  ...
# 596         서울특별시 중랑구 면목로 3101522-3232)
# 597             서울특별시 중랑구 망우로 307 (상봉동)
# 598  서울특별시 중랑구 동일로 952 (묵동, 로프트원 태릉입구역)
# 599           서울특별시 중랑구 양원역로10길 3 (망우동)
# 600        서울특별시 중랑구 봉화산로 35 1522-3232)
#
# [601 rows x 4 columns]

# %%
SB_stores.columns = ['매장이름', 'lat', 'lng', '주소']
SB_stores
# Out:
#         매장이름                lat                 lng  \
# 0    역삼아레나빌딩          37.501087          127.043069
# 1     논현역사거리          37.510178          127.022223
# 2    신사역성일빌딩         37.5139309         127.0206057
# 3     국기원사거리          37.499517          127.031495
# 4    대치재경빌딩R          37.494668          127.062583
# ..       ...                ...                 ...
# 596     사가정역          37.579594          127.087966
# 597      상봉역           37.59689           127.08647
# 598       묵동          37.615368          127.076633
# 599      양원역   37.6066536267232    127.106359790053
# 600      중화역  37.60170912407773  127.07841136432036
#
#                                      주소
# 0               서울특별시 강남구 언주로 425 (역삼동)
# 1              서울특별시 강남구 강남대로 538 (논현동)
# 2              서울특별시 강남구 강남대로 584 (논현동)
# 3              서울특별시 강남구 테헤란로 125 (역삼동)
# 4            서울특별시 강남구 남부순환로 2947 (대치동)
# ..                                  ...
# 596         서울특별시 중랑구 면목로 3101522-3232)
# 597             서울특별시 중랑구 망우로 307 (상봉동)
# 598  서울특별시 중랑구 동일로 952 (묵동, 로프트원 태릉입구역)
# 599           서울특별시 중랑구 양원역로10길 3 (망우동)
# 600        서울특별시 중랑구 봉화산로 35 1522-3232)
#
# [601 rows x 4 columns]

# %%
## 지역구 이름 컬럼 만들기 1개 예시

tmp_gu = SB_stores["주소"][0].split()[1]
tmp_gu
# Out:
# '강남구'

# %%
## 위의 작업 반복해서 구 컬럼 만들기

SB_stores["구"] = [items.split()[1] for items in SB_stores["주소"]]
SB_stores.set_index("매장이름", inplace=True)
SB_stores
# Out:
#                        lat                 lng  \
# 매장이름
# 역삼아레나빌딩          37.501087          127.043069
# 논현역사거리           37.510178          127.022223
# 신사역성일빌딩         37.5139309         127.0206057
# 국기원사거리           37.499517          127.031495
# 대치재경빌딩R          37.494668          127.062583
# ...                    ...                 ...
# 사가정역             37.579594          127.087966
# 상봉역               37.59689           127.08647
# 묵동               37.615368          127.076633
# 양원역       37.6066536267232    127.106359790053
# 중화역      37.60170912407773  127.07841136432036
#
#                                          주소    구
# 매장이름
# 역삼아레나빌딩             서울특별시 강남구 언주로 425 (역삼동)  강남구
# 논현역사거리             서울특별시 강남구 강남대로 538 (논현동)  강남구
# 신사역성일빌딩            서울특별시 강남구 강남대로 584 (논현동)  강남구
# 국기원사거리             서울특별시 강남구 테헤란로 125 (역삼동)  강남구
# 대치재경빌딩R          서울특별시 강남구 남부순환로 2947 (대치동)  강남구
# ...                                     ...  ...
# 사가정역            서울특별시 중랑구 면목로 3101522-3232)  중랑구
# 상봉역                 서울특별시 중랑구 망우로 307 (상봉동)  중랑구
# 묵동       서울특별시 중랑구 동일로 952 (묵동, 로프트원 태릉입구역)  중랑구
# 양원역               서울특별시 중랑구 양원역로10길 3 (망우동)  중랑구
# 중화역            서울특별시 중랑구 봉화산로 35 1522-3232)  중랑구
#
# [601 rows x 4 columns]

# %%
# 위도, 경도 실수형으로 만들기

SB_stores["lat"] = SB_stores["lat"].astype("float")
SB_stores["lng"] = SB_stores["lng"].astype("float")

SB_stores
# Out:
#                lat         lng                                  주소    구
# 매장이름
# 역삼아레나빌딩  37.501087  127.043069             서울특별시 강남구 언주로 425 (역삼동)  강남구
# 논현역사거리   37.510178  127.022223            서울특별시 강남구 강남대로 538 (논현동)  강남구
# 신사역성일빌딩  37.513931  127.020606            서울특별시 강남구 강남대로 584 (논현동)  강남구
# 국기원사거리   37.499517  127.031495            서울특별시 강남구 테헤란로 125 (역삼동)  강남구
# 대치재경빌딩R  37.494668  127.062583          서울특별시 강남구 남부순환로 2947 (대치동)  강남구
# ...            ...         ...                                 ...  ...
# 사가정역     37.579594  127.087966         서울특별시 중랑구 면목로 3101522-3232)  중랑구
# 상봉역      37.596890  127.086470             서울특별시 중랑구 망우로 307 (상봉동)  중랑구
# 묵동       37.615368  127.076633  서울특별시 중랑구 동일로 952 (묵동, 로프트원 태릉입구역)  중랑구
# 양원역      37.606654  127.106360           서울특별시 중랑구 양원역로10길 3 (망우동)  중랑구
# 중화역      37.601709  127.078411        서울특별시 중랑구 봉화산로 35 1522-3232)  중랑구
#
# [601 rows x 4 columns]

# %%
SB_stores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 601 entries, 역삼아레나빌딩 to 중화역
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   lat     601 non-null    float64
#  1   lng     601 non-null    float64
#  2   주소      601 non-null    object
#  3   구       601 non-null    object
# dtypes: float64(2), object(2)
# memory usage: 23.5+ KB

# %%
### 스타벅스 매장 정리 데이터 저장하기

SB_stores.to_csv("./Data/SB_stores.csv", encoding="euc-kr")

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# # 2. 서울시의 이디야 매장의 이름과 주소, 구 이름을 pandas data frame으로 정리
#
# - 매장 정보 찾기 플로우
#     - 1. 이디야 공식 매장 -> 결측값 발생
#     - 2. Google Maps API -> 검색안되는 장소 있음
#     - 3. 구글지도 켜서 직접 추출....

# %% [markdown]
# ## 2 - 1. 이디야 홈페이지 셀레니움 작업

# %%
# 셀레니움에서 웹드라이버 기능을 쓰겠다.
import time
from selenium.webdriver import ActionChains
from selenium.webdriver.common.by import By
from selenium import webdriver

# 웹드라이버 방법중 크롬을 쓰겠다. 크롬 드라이버를 넣어주겠다.
driver = webdriver.Chrome(executable_path="../driver/chromedriver.exe") # 경로, 권한 설정 잘해줘야
action = ActionChains(driver)
driver.get("https://www.ediya.com/")
time.sleep(3)

# 화면 최대 크기 설정 - 전체화면
driver.maximize_window()

# %%
# 매장찾기 버튼 누르기

store_tag = driver.find_element(By.CSS_SELECTOR,'body > header > div > div > div.gnb_wrap > div.top_util > ul.top_members > li.store > a')
store_tag.click()
time.sleep(2)

# %%
## 지도 검색창 까지 스크롤 하기 (지도 하단의 kakao 이미지태그 까지)

# x,y 픽셀까지 스크롤하기
#search_map_tag = driver.execute_script("window.scrollTo(0, 570)")

search_map_tag = driver.find_element(By.CSS_SELECTOR,"#map > div:nth-child(2) > div:nth-child(2) > a > img")
action.move_to_element(search_map_tag).perform()

# %%
## 주소 검색 버튼을 누르기

search_loc = driver.find_element(By.CSS_SELECTOR,'#contentWrap > div.contents > div > div.store_search_pop > ul > li:nth-child(2) > a')
search_loc.click()
time.sleep(2)

# %% [markdown]
# ---

# %% [markdown]
# ## 2 - 2. 주소를 검색하기 위해 스타벅스의 구 컬럼을 가져오기

# %%
search_gu_list = pd.read_csv("./Data/SB_stores.csv", encoding="euc-kr",usecols=["구"])
search_gu_list
# Out:
#        구
# 0    강남구
# 1    강남구
# 2    강남구
# 3    강남구
# 4    강남구
# ..   ...
# 596  중랑구
# 597  중랑구
# 598  중랑구
# 599  중랑구
# 600  중랑구
#
# [601 rows x 1 columns]

# %%
# 중복검색을 피하기 위해 unique로 리스트를 만든다.

search_gu_list = search_gu_list["구"].unique()
search_gu_list
# Out:
# array(['강남구', '강북구', '강서구', '관악구', '광진구', '금천구', '노원구', '도봉구', '동작구',
#        '마포구', '서대문구', '서초구', '성북구', '송파구', '양천구', '영등포구', '은평구', '종로구',
#        '중구', '강동구', '구로구', '동대문구', '성동구', '용산구', '중랑구'], dtype=object)

# %% [markdown]
# ---

# %% [markdown]
# ## 2 - 3. 한 개 예시로 검색 후 리스트에 담기
# - 예시) 강남구 검색어 -> 돋보기 버튼 클릭 -> 정보 추출(뷰숲) -> 강남구 검색어(clear) -> 다른 구 검색 .....

# %%
## 주소 검색 창에 구 이름을 검색어로 넣기

tmp_gu_keyword = driver.find_element(By.CSS_SELECTOR,'#keyword')
tmp_gu_keyword.send_keys(search_gu_list[0])
time.sleep(2)

# %%
## 주소 검색 창에 구 이름을 검색어로 넣기 -> 돋보기 버튼 누르기

search_btn = driver.find_element(By.CSS_SELECTOR,'#keyword_div > form > button')
search_btn.click()
time.sleep(2)

# %% [markdown]
# ##### 현재 페이지 뷰숲 불러와서 작업하기

# %%
# 현재 화면의 html 코드를 가져와서 뷰숲으로 작업하기

from bs4 import BeautifulSoup

req = driver.page_source
soup = BeautifulSoup(req, 'html.parser')

# %%
# 매장리스트 태그 접근

store_list_tag = soup.select('#placesList > .item')
len(store_list_tag)
# Out:
# 40

# %%
# 리스트에서 하나 정보 추출하기


# 매장 이름
sample_name = store_list_tag[1].select_one('a > dl > dt').text


# 매장 위도
sample_lat = store_list_tag[1].select_one('a')['onclick'].split("'")[3]


# 매장 경도
sample_lng = store_list_tag[1].select_one('a')['onclick'].split("'")[1]

# 매장 주소
sample_addr = store_list_tag[1].select_one('a > dl > dd').text


print(sample_name)
print(sample_lat)
print(sample_lng)
print(sample_addr)
# Out:
# 강남구청역아이티웨딩점
# 37.51654171724045
# 127.0401601992311
# 서울 강남구 학동로 338 (논현동, 강남파라곤)

# %%
## 반복문으로 하나의 구의 매장들 리스트에 넣기
from bs4 import BeautifulSoup

ED_tmp_store_names = []
ED_tmp_store_lats = []
ED_tmp_store_lngs = []
ED_tmp_store_addrs = []

for stores in store_list_tag:
    
    # 매장 이름
    ED_tmp_store_names.append(stores.select_one('a > dl > dt').text)


    # 매장 위도
    ED_tmp_store_lats.append(stores.select_one('a')['onclick'].split("'")[3])


    # 매장 경도
    ED_tmp_store_lngs.append(stores.select_one('a')['onclick'].split("'")[1])

    # 매장 주소
    ED_tmp_store_addrs.append(stores.select_one('a > dl > dd').text)

# %%
len(ED_tmp_store_names), len(ED_tmp_store_lats), len(ED_tmp_store_lngs), len(ED_tmp_store_addrs)
# Out:
# (40, 40, 40, 40)

# %%
tmp_gu_keyword.clear()

# %% [markdown]
# ---

# %% [markdown]
# ## 2 - 4. 반복문으로 매장 정보 전부 추출하기
#
# - 반복문 구조 설명
#
# ```
# for in 스타벅스 구 컬럼 :
#     검색창에 구 이름 삽입
#     돋보기 버튼 클릭
#     현재 화면의 html 코드를 가져오기
#     현재 검색한 구의 매장 리스트 태그 접근
#
#     for in 검색 후 결과 soup:
#         위도, 경도, 매장이름, 매장 주소 정보 추출
#
#     검색창 클리어
# ```

# %%
## 주소 검색 창에 구 이름을 검색어로 넣기
from bs4 import BeautifulSoup
from tqdm import notebook

ED_store_names = []
ED_store_lats = []
ED_store_lngs = []
ED_store_addrs = []

for gu in notebook.tqdm(search_gu_list):
    
    # 1. 구 이름 검색창에 넣기
    gu_keyword = driver.find_element(By.CSS_SELECTOR,'#keyword')
    gu_keyword.send_keys("서울 "+str(gu))
    #time.sleep(2)
    
    # 2. 검색창 돋보기 버튼 클릭하기
    search_btn = driver.find_element(By.CSS_SELECTOR,'#keyword_div > form > button')
    search_btn.click()
    time.sleep(3)
    
    # 3. 현재 페이지 html 코드 가져오기   
    req = driver.page_source
    soup = BeautifulSoup(req, 'html.parser')
    time.sleep(1)

    # 4. 검색된 매장 리스트 태그에 접근
    store_list_tag = soup.select('#placesList > .item')

    # 5. 매장 리스트에서 정보 추출하기
    for stores in store_list_tag:
    
        # 매장 이름
        ED_store_names.append(stores.select_one('a > dl > dt').text)

        # 매장 위도
        ED_store_lats.append(stores.select_one('a')['onclick'].split("'")[3])

        # 매장 경도
        ED_store_lngs.append(stores.select_one('a')['onclick'].split("'")[1])

        # 매장 주소
        ED_store_addrs.append(stores.select_one('a > dl > dd').text)

    gu_keyword.clear()
# Out:
#   0%|          | 0/25 [00:00<?, ?it/s]

# %%
# 데이터 확인 1

len(ED_store_names), len(ED_store_lats), len(ED_store_lngs), len(ED_store_addrs)
# Out:
# (660, 660, 660, 660)

# %%
# 데이터 확인 2

ED_store_lngs
# Out:
# ['0',
#  '127.0401601992311',
#  '127.02810578707652',
#  '127.05242928262568',
#  '서울 강남구 도산대로37길 20 (신사동)',
#  '127.107863694133',
#  '127.1031720971561',
#  '127.06742226515867',
#  '서울 강남구 언주로 711 (논현동)',
#  '127.07764131137398',
#  '127.04304591726503',
#  '서울 강남구 논현동 ',
#  '127.06310437319587',
#  '서울 강남구 테헤란로88길 10 (대치동)',
#  '127.053299510545',
#  '서울 강남구 테헤란로107길 11 (삼성동)',
#  '127.04806966822704',
#  '127.048192060882',
#  '0',
#  '127.10304411368496',
#  '127.02145819084597',
#  '127.02186508143391',
#  '서울 강남구 선릉로161길 20 (신사동)',
#  '서울 강남구 논현로63길 16 (역삼동, 역삼종합시장 더블루)',
#  '127.0439944465106',
#  '127.03523956508853',
#  '127.04811298239548',
#  '0',
#  '127.04292899982501',
#  '0',
#  '서울 강남구 테헤란로4길 46 (역삼동, 쌍용플래티넘밸류)',
#  '0',
#  '127.032981540064',
#  '127.08160067456867',
#  '127.05035288418118',
#  '127.049146860404',
#  '서울 강남구 개포로 218 (개포동)',
#  '127.03312378880225',
#  '127.033652198273',
#  '127.056118735013',
#  '127.016163948133',
#  '127.022605961559',
#  '127.034460650104',
#  '127.031024695473',
#  '127.02970277545434',
#  '서울 강북구 삼양로 118 (미아동)',
#  '127.02547799375',
#  '127.028752360124',
#  '127.03987378053',
#  '127.005613427587',
#  '127.016024676372',
#  '0',
#  '0',
#  '0',
#  '0',
#  '0',
#  '0',
#  '126.855918740576',
#  '서울 강서구 화곡로 292 (화곡동, 서광프리메라)',
#  '0',
#  '126.806994113323',
#  '0',
#  '126.810682079138',
#  '서울 강서구 까치산로 182 (화곡동)',
#  '0',
#  '126.83670247916808',
#  '0',
#  '126.86312283631494',
#  '126.84945198496683',
#  '126.826956189701',
#  '126.826675489517',
#  '126.829169795133',
#  '126.83523920295',
#  '126.829290828058',
#  '126.826138036672',
#  '126.812631152778',
#  '126.811777075121',
#  '126.82384490815572',
#  '126.809951413051',
#  '126.821451112442',
#  '0',
#  '서울 강서구 양천로 583 (염창동)',
#  '0',
#  '서울 강서구 등촌로5길 80 (화곡동)',
#  '서울 강서구 화곡로 133 (화곡동)',
#  '126.84424724638545',
#  '0',
#  '0',
#  '서울 관악구 관악로 164 (봉천동, 대우디오슈페리움1단지)',
#  '126.95603357684',
#  '126.902896907397',
#  '서울 관악구 남부순환로 1915 (봉천동)',
#  '126.911256043771',
#  '126.919395468118',
#  '서울 관악구 과천대로 909 (남현동, 남현프라자)',
#  '서울 관악구 신림로 91 (신림동)',
#  '서울 관악구 보라매로 62 (봉천동, 보라매삼성아파트)',
#  '서울 관악구 은천로 23 (봉천동)',
#  '서울 관악구 남부순환로 1725 (봉천동)',
#  '서울 관악구 남부순환로 1874 (봉천동)',
#  '서울 관악구 과천대로 951 (남현동)',
#  '126.9490007619789',
#  '0',
#  '126.918942273894',
#  '126.921883674693',
#  '서울 관악구 호암로26길 17 (신림동)',
#  '126.915984298817',
#  '0',
#  '126.93620717411919',
#  '126.93014982439058',
#  '0',
#  '126.925430749958',
#  '0',
#  '0',
#  '0',
#  '127.03562908437665',
#  '0',
#  '서울 광진구 아차산로 229 (화양동, 한림타워)',
#  '0',
#  '0',
#  '서울 광진구 자양로 136 (구의동)',
#  '서울 광진구 광나루로 508 (구의동)',
#  '0',
#  '127.0893030454462',
#  '0',
#  '0',
#  '127.06724151732122',
#  '127.03603440263092',
#  '0',
#  '0',
#  '0',
#  '서울 광진구 자양로 46 (자양동)',
#  '서울 광진구 자양번영로 34 (자양동, 제이원하이텔)',
#  '서울 광진구 용마산로 111 (중곡동)',
#  '127.087723525693',
#  '서울 광진구 능동로 407 (중곡동)',
#  '0',
#  '서울 금천구 가산디지털2로 70 (가산동)',
#  '서울 금천구 가산로 111 (가산동)',
#  '0',
#  '서울 금천구 벚꽃로 244 (가산동)',
#  '서울 금천구 가산디지털1로 196 (가산동)',
#  '126.8901033556771',
#  '서울 금천구 가산디지털2로 123 (가산동)',
#  '126.88749549372684',
#  '서울 금천구 시흥대로 291 (독산동, 금천롯데캐슬골드파크3차)',
#  '126.9032865178164',
#  '126.90200430635853',
#  '0',
#  '서울 금천구 시흥대로 150 (시흥동)',
#  '126.90472649315366',
#  '서울 금천구 독산로 124 (시흥동)',
#  '서울 금천구 시흥동',
#  '0',
#  '서울 금천구 시흥대로 88 (시흥동, 오복빌딩)',
#  '서울 금천구 금하로 748 (시흥동)',
#  '서울 금천구 금하로 690 (시흥동)',
#  '서울 노원구 동일로192길 5 (공릉동)',
#  '서울 노원구 광운로 29 (월계동)',
#  '서울 노원구 동일로 1393 (상계동)',
#  '서울 노원구 노원로 452 (상계동)',
#  '서울 노원구 상계로 313 (상계동)',
#  '서울 노원구 동일로 1541 (상계동)',
#  '0',
#  '서울 노원구 한글비석로 409 (상계동) 1~2층',
#  '서울 노원구 덕릉로 698 (중계동)',
#  '서울 노원구 동일로 1650 (상계동)',
#  '0',
#  '서울 노원구 한글비석로 57 (하계동, 세이브존)',
#  '127.068915344466',
#  '서울 노원구 동일로 1689 (상계동, 하이베라스)',
#  '0',
#  '127.061979778612',
#  '0',
#  '서울 노원구 월계동 ',
#  '0',
#  '127.0826133945026',
#  '0',
#  '서울 노원구 동일로204가길 34 (중계동)',
#  '서울 노원구 덕릉로73길 18 (중계동)',
#  '127.077885277951',
#  '0',
#  '127.01319601269354',
#  '서울 도봉구 해등로 157 (쌍문동)',
#  '127.04374413595103',
#  '서울 도봉구 도봉로 823 (도봉동)',
#  '서울 도봉구 도봉로181길 18 (도봉동)',
#  '0',
#  '0',
#  '0',
#  '0',
#  '0',
#  '127.013556949839',
#  '127.038109547969',
#  '127.02717853006696',
#  '127.034706714207',
#  '127.036320646169',
#  '127.03874807786094',
#  '127.04959433985911',
#  '127.049667391336',
#  '127.05250451283373',
#  '127.05139242088684',
#  '서울 도봉구 해등로16길 61 (창동)',
#  '127.035653272558',
#  '서울 동작구 사당로17가길 13 (사당동)',
#  '0',
#  '0',
#  '126.93865425871968',
#  '126.94082532227891',
#  '126.908076731256',
#  '126.92834765518518',
#  '126.916661704502',
#  '0',
#  '서울 동작구 동작대로7길 100 (사당동)',
#  '서울 동작구 동작대로 45 (사당동)',
#  '서울 동작구 상도로 277 (상도1동)',
#  '126.94715442128768',
#  '서울 동작구 사당로 2 (상도동)',
#  '126.92914752489297',
#  '0',
#  '0',
#  '126.9530308556',
#  '0',
#  '0',
#  '0',
#  '126.964738341052',
#  '126.950886259458',
#  '126.954062019715',
#  '0',
#  '126.95051136853504',
#  '서울 마포구 월드컵로 196 (성산동)',
#  '126.905804329554',
#  '0',
#  '126.905265725284',
#  '0',
#  '서울 마포구 월드컵로 147 (망원동)',
#  '0',
#  '0',
#  '서울 마포구 월드컵북로 375 (상암동)',
#  '서울 마포구 월드컵북로56길 9 (상암동)',
#  '서울 마포구 성암로13길 58 (상암동)',
#  '서울 마포구 월드컵로 240 (성산동)',
#  '서울 마포구 월드컵북로 137 (성산동)',
#  '서울 마포구 성미산로 78 (성산동)',
#  '126.945660437538',
#  '서울 마포구 서강로 135 (노고산동)',
#  '126.93551824572988',
#  '126.933116598433',
#  '0',
#  '0',
#  '서울 마포구 망원로 21 (망원동)',
#  '서울 마포구 양화로1길 21 (합정동)',
#  '0',
#  '서울 마포구 독막로2길 5 (합정동)',
#  '서울 마포구 양화로11길 54 (서교동)',
#  '서울 마포구 양화로 45 (서교동, 메세나폴리스)',
#  '0',
#  '0',
#  '서울 서대문구 수색로 100 (북가좌동, DMC래미안e편한세상)',
#  '0',
#  '서울 서대문구 신촌로 5 (창천동)',
#  '서울 서대문구 거북골로 35 (남가좌동)',
#  '0',
#  '서울 서대문구 홍제동 ',
#  '서울 서대문구 증가로 257 (북가좌동)',
#  '126.93569228371322',
#  '서울 서대문구 냉천동',
#  '0',
#  '서울 서대문구 신촌로 87-20 (창천동)',
#  '0',
#  '서울 서대문구 연세로12길 10 (창천동)',
#  '서울 서대문구 연희로 117 (연희동)',
#  '126.94592111849613',
#  '126.962192415514',
#  '서울 서대문구 통일로 510 (홍은동, 북한산 더샵)',
#  '서울 서대문구 홍제동',
#  '127.00241119724721',
#  '127.01711123409879',
#  '0',
#  '127.00852440751981',
#  '127.00399194893603',
#  '127.0030193959796',
#  '서울 서초구 서초동 ',
#  '0',
#  '127.0050532634284',
#  '126.999783720903',
#  '0',
#  '서울 서초구 동광로 1 (방배동, 대양빌딩)',
#  '127.00568884262598',
#  '서울 서초구 서초동 ',
#  '127.01448803642147',
#  '0',
#  '127.01625285612394',
#  '127.0329589189837',
#  '127.019386390307',
#  '서울 서초구 동산로 60 (양재동, 화성빌딩)',
#  '127.031487443707',
#  '0',
#  '서울 서초구 청계산로 10 (양재동, 농협하나로클럽)',
#  '127.01212053082338',
#  '0',
#  '0',
#  '서울 서초구 신원동',
#  '127.044550865871',
#  '서울 서초구 방배로 234 우신빌딩',
#  '서울 성북구 개운사길 30 (안암동5가)',
#  '127.029558844368',
#  '0',
#  '서울 성북구 동소문로 119 (동선동4가)',
#  '0',
#  '0',
#  '127.042688569342',
#  '서울 성북구 동소문로13길 5 (동소문동4가)',
#  '서울 성북구 보문로 111 (보문동2가)',
#  '0',
#  '127.06226070129833',
#  '127.015893755022',
#  '0',
#  '127.02202493345699',
#  '서울 성북구 오패산로 99 (하월곡동)',
#  '127.04566819751201',
#  '서울 성북구 종암로 167 (하월곡동, 동일하이빌뉴시티)',
#  '127.052463640045',
#  '127.051043617995',
#  '서울 성북구 월계로40길 7 (장위동)',
#  '127.045615723434',
#  '0',
#  '0',
#  '0',
#  '0',
#  '0',
#  '서울 성북구 오패산로 16 (하월곡동)',
#  '0',
#  '0',
#  '127.119106729654',
#  '127.124961768886',
#  '127.11673189696464',
#  '127.12087308454156',
#  '127.13573191111163',
#  '127.14434073545736',
#  '127.115481243131',
#  '127.12670032405158',
#  '127.126340658567',
#  '127.120933640924',
#  '서울 송파구 백제고분로48길 3 (방이동)',
#  '0',
#  '127.120016251041',
#  '127.095799159025',
#  '127.08075330646',
#  '127.104455184706',
#  '127.108284732156',
#  '127.105841889845',
#  '127.108394911161',
#  '127.12526318784414',
#  '127.11794613172696',
#  '127.14280133733737',
#  '0',
#  '서울 송파구 충민로2길 28 (장지동, 대진플라자2)',
#  '0',
#  '127.124913859704',
#  '127.113590203805',
#  '127.1258397162108',
#  '127.1305037107547',
#  '0',
#  '127.13191560436993',
#  '127.14207669027857',
#  '127.13442428248332',
#  '127.085852293902',
#  '127.0993615087665',
#  '127.079181383259',
#  '서울 양천구 오목로 48 (신월동)',
#  '126.862615322582',
#  '0',
#  '0',
#  '0',
#  '126.863821477728',
#  '126.840692066592',
#  '0',
#  '126.85550236470392',
#  '126.85263139671464',
#  '서울 양천구 오목로 227 (신정동)',
#  '0',
#  '서울 양천구 목동서로 155 (목동)',
#  '0',
#  '서울 양천구 화곡로 50 (신월동)',
#  '0',
#  '126.828923065237',
#  '0',
#  '0',
#  '서울 양천구 신정로11길 50-15 (신정동)',
#  '서울 양천구 오목로 155 (신정동)',
#  '0',
#  '서울 양천구 오목로 319 (목동)',
#  '서울 양천구 신목로 102 (목동)',
#  '126.928930989749',
#  '126.919916432847',
#  '126.917843631999',
#  '126.891103928762',
#  '서울 영등포구 버드나루로 87 (영등포동7가)',
#  '0',
#  '서울 영등포구 당산로 159 (당산동4가)',
#  '126.9028549432193',
#  '서울 영등포구 대림로 212 (대림동)',
#  '126.895919529889',
#  '0',
#  '서울 영등포구 도신로15길 40 (도림동, 도림빌딩)',
#  '126.939136417577',
#  '서울 영등포구 여의대방로 141 (신길동)',
#  '126.92108595764988',
#  '서울 영등포구 양평로 126 (양평동5가)',
#  '126.92152601914932',
#  '0',
#  '서울 영등포구 도림로 280 (신길동)',
#  '0',
#  '서울 영등포구 도신로 229 (신길동)',
#  '서울 영등포구 신풍로 52-1 (신길동)',
#  '0',
#  '126.930769729764',
#  '126.930048684376',
#  '126.923991634451',
#  '126.90422425738349',
#  '서울 영등포구 당산로 110 (당산동3가)',
#  '126.888600855285',
#  '서울 영등포구 영신로19길 15 (영등포동)',
#  '서울 영등포구 영등포로35길 19 (영등포동6가)',
#  '서울 영등포구 국회대로54길 10 (영등포동7가, 아크로타워 스퀘어)',
#  '서울 영등포구 경인로 775 (문래동3가)',
#  '126.90613304012865',
#  '서울 영등포구 영중로 37 (영등포동4가)',
#  '126.907665995469',
#  '127.02455282046348',
#  '서울 영등포구 버드나루로 51 (영등포동2가)',
#  '126.923399003703',
#  '126.91093600723607',
#  '서울 은평구 갈현로 268 (갈현동)',
#  '126.91762675639762',
#  '0',
#  '126.92690582152823',
#  '126.934630829335',
#  '126.91882273114795',
#  '126.92212973358569',
#  '126.92942389241764',
#  '0',
#  '126.93174133362822',
#  '126.91361081200473',
#  '126.89630783479784',
#  '126.91070049318746',
#  '126.92093711755628',
#  '126.922124290438',
#  '126.91863338447128',
#  '126.919884176889',
#  '서울 은평구 통일로 825 (대조동)',
#  '서울 은평구 통일로 876 (불광동)',
#  '126.92948914955393',
#  '126.92016492662756',
#  '126.91561001336949',
#  '126.91715178773087',
#  '126.91657705577255',
#  '126.906550600654',
#  '126.972206795305',
#  '126.970696336246',
#  '126.97565344843615',
#  '0',
#  '서울 종로구 낙원동 ',
#  '0',
#  '0',
#  '127.00805518188871',
#  '서울 종로구 종로 354 (숭인동)',
#  '서울 종로구 대학로 81-1 (연건동)',
#  '0',
#  '126.982701926649',
#  '0',
#  '0',
#  '서울 종로구 성균관로 8 (명륜2가)',
#  '서울 종로구 숭인동길 6 (숭인동)',
#  '127.021476077131',
#  '0',
#  '서울 종로구 김상옥로 1 (인의동)',
#  '127.00182933693897',
#  '127.00218468908556',
#  '서울 종로구 수송동',
#  '0',
#  '0',
#  '0',
#  '126.99142858488984',
#  '서울 종로구 지봉로 64 (숭인동)',
#  '0',
#  '0',
#  '서울 종로구 창경궁로 258-15 (명륜2가)',
#  '126.98717557400126',
#  '서울 중구 세종대로1길 11 (봉래동1가)',
#  '0',
#  '서울 중구 다동길 46 (다동)',
#  '126.9986915916533',
#  '0',
#  '0',
#  '126.96257532807736',
#  '126.985404271845',
#  '서울 중구 퇴계로 103 (충무로1가)',
#  '126.983858910559',
#  '126.973094520683',
#  '126.978729588014',
#  '0',
#  '0',
#  '0',
#  '0',
#  '0',
#  '0',
#  '서울 중구 청파로 464 (중림동)',
#  '0',
#  '0',
#  '0',
#  '0',
#  '0',
#  '126.974582779311',
#  '126.97740146915775',
#  '서울 중구 남대문로 29-2 (남대문로3가)',
#  '서울 중구 청계천로 400 (황학동, 롯데캐슬베네치아)',
#  '서울 중구 퇴계로 72 (회현동1가, 리더스뷰남산)',
#  '127.172575598882',
#  '0',
#  '127.12985994805354',
#  '127.147402025244',
#  '0',
#  '127.17410624484566',
#  '127.16370018873648',
#  '127.15518054387726',
#  '서울 강동구 천호대로 1132 (성내동)',
#  '서울 강동구 양재대로 1471 (길동)',
#  '서울 강동구 명일로 200 (길동)',
#  '0',
#  '127.14556505383719',
#  '127.145789262651',
#  '0',
#  '127.17398322022565',
#  '127.14074049194033',
#  '127.128126213246',
#  '127.134728442286',
#  '0',
#  '0',
#  '0',
#  '127.12456936024019',
#  '127.134809493652',
#  '서울 강동구 올림픽로 665 (천호동)',
#  '126.85837744421302',
#  '0',
#  '0',
#  '0',
#  '126.8582904039366',
#  '126.86392369544526',
#  '0',
#  '0',
#  '126.850139541298',
#  '126.890315032666',
#  '126.82937821925746',
#  '126.87671651690317',
#  '0',
#  '126.88108330547095',
#  '서울 구로구 디지털로32길 43 (구로동)',
#  '126.89208440149883',
#  '126.88136511388151',
#  '126.87192053744891',
#  '서울 구로구 디지털로27길 127 (가리봉동)',
#  '서울 구로구 경인로47길 14 (고척동)',
#  '126.862695769372',
#  '0',
#  '0',
#  '0',
#  '서울 구로구 오류로8길 65 (오류동)',
#  '0',
#  '서울 구로구 천왕로 36 (천왕동)',
#  '127.05250416385545',
#  '127.05111084006763',
#  '127.05611323484102',
#  '127.061880899304',
#  '127.040640800113',
#  '서울 동대문구 무학로 104 (용두동)',
#  '서울 동대문구 답십리로63길 131 (장안동)',
#  '127.0548189288785',
#  '127.02493296369806',
#  '127.06125986481157',
#  '서울 동대문구 왕산로 68 (용두동)',
#  '서울 동대문구 고산자로 413-1 (용두동)',
#  '서울 동대문구 신이문로 19 (이문동)',
#  '서울 동대문구 답십리로 309 (장안동)',
#  '서울 동대문구 장한로 43 (장안동)',
#  '127.07077591338621',
#  '서울 동대문구 사가정로25길 42 (장안동)',
#  '127.06144791110912',
#  '서울 동대문구 답십리로 77 (전농동)',
#  '서울 동대문구 사가정로 132 (전농동)',
#  '0',
#  '서울 동대문구 답십리로 264 (장안동)',
#  '127.06058696054686',
#  '127.05749583678211',
#  '서울 성동구 난계로 35 (금호동1가)',
#  '서울 성동구 용답19길 17-1 (용답동)',
#  '서울 성동구 상원길 38-1 (성수동1가)',
#  '서울 성동구 고산자로 339-2 (마장동)',
#  '0',
#  '0',
#  '서울 성동구 고산자로 269 (도선동)',
#  '서울 성동구 성수이로 118 (성수동2가)',
#  '0',
#  '0',
#  '0',
#  '서울 성동구 매봉길 12 (옥수동)',
#  '0',
#  '서울 성동구 왕십리광장로 17 (행당동)',
#  '0',
#  '0',
#  '0',
#  '0',
#  '0',
#  '서울 성동구 사근동길 4 (행당동)',
#  '서울 성동구 고산자로 201 (행당동)',
#  '127.00692431290224',
#  '서울 용산구 이촌로77길 19 (이촌동)',
#  '서울 용산구 후암로 93 (동자동)',
#  '0',
#  '서울 용산구 한강대로 289 (갈월동)',
#  '0',
#  '126.9611373908156',
#  '126.951642152118',
#  '서울 용산구 한강대로 52-1 (한강로3가)',
#  '126.969413497587',
#  '126.96220762686157',
#  '126.977694955629',
#  '서울 용산구 원효로 257 (원효로1가)',
#  '126.993425922089',
#  '0',
#  '127.094182772191',
#  '0',
#  '127.09415879594557',
#  '127.092756577852',
#  '127.076897926489',
#  '127.08048931056359',
#  '127.079680860838',
#  '0',
#  '127.086826066156',
#  '서울 중랑구 신내로 211 (신내동)',
#  '127.083196727099',
#  '서울 중랑구 면목로 325 (면목동)',
#  '서울 중랑구 망우로 353 (상봉동, 상봉 프레미어스 엠코)',
#  '127.08342099906',
#  '서울 중랑구 망우로 316 (상봉동)',
#  '127.087790157773',
#  '127.09776667760102',
#  '127.09544803898843',
#  '0',
#  '서울 중랑구 봉화산로 215 (신내동)',
#  '127.10675146670297',
#  '127.085692400436',
#  '127.099371847976',
#  '0',
#  '127.0775356804549',
#  '0',
#  '127.079542626772',
#  '서울 중랑구 동일로 815, 1층',
#  '127.08413727538176']

# %%
# 추출완료 - driver 종료
driver.quit()

# %% [markdown]
# ## 2 - 5. 위도 경도가 결측값 파악
#
# - 결측값을 판단하자
#     - 우리나라 경도는 126 ~ 128 사이의 값, 위도는 35 ~ 37 사이다. 그 외는 전부 결측값이다.
#     - 경도를 정수형으로 바꿔 결측값을 판단하자. (문자열인 경우 안바뀜)
#         - 바뀐다 => 126 ~ 128 사이값이 아니다 => 결측값
#         - 안 바뀐다. => 결측값

# %% [markdown]
# #### 데이터프레임으로 작업하기 위해 먼저 데이터를 병합한다.

# %%
import pandas as pd
import numpy as np

# %%
ED_stores = pd.DataFrame(zip(ED_store_names, ED_store_lats, ED_store_lngs, ED_store_addrs))
ED_stores
# Out:
#                0                  1                        2  \
# 0        강남YMCA점                  0                        0
# 1    강남구청역아이티웨딩점  37.51654171724045        127.0401601992311
# 2        강남논현학동점  37.51408005446769       127.02810578707652
# 3          강남대치점  37.50133876179308       127.05242928262568
# 4          강남도산점                  4  서울 강남구 도산대로37길 20 (신사동)
# ..           ...                ...                      ...
# 655        중랑묵동점  37.61335268312136        127.0775356804549
# 656         중랑역점                  0                        0
# 657         중화동점   37.5993838458016         127.079542626772
# 658         중화역점                 28       서울 중랑구 동일로 815, 1층
# 659        화랑대역점  37.61954020149987       127.08413727538176
#
#                                 3
# 0                      서울 강남구 논현동
# 1     서울 강남구 학동로 338 (논현동, 강남파라곤)
# 2         서울 강남구 논현로131길 28 (논현동)
# 3      서울 강남구 역삼로 415 (대치동, 성진빌딩)
# 4         서울 강남구 도산대로37길 20 (신사동)
# ..                            ...
# 655  서울 중랑구 동일로 932 (묵동, 묵동자이아파트)
# 656          서울 중랑구 망우로 198 (상봉동)
# 657        서울 중랑구 동일로129길 1 (중화동)
# 658            서울 중랑구 동일로 815, 1층
# 659   서울 중랑구 신내로25가길 2 (묵동, 현동학당)
#
# [660 rows x 4 columns]

# %% [markdown]
# #### 컬럼명, 인덱스를 재지정한다.

# %%
ED_stores.columns = ["매장이름", "lat", "lng", "주소"]
ED_stores.set_index('매장이름', inplace=True)
ED_stores
# Out:
#                            lat                      lng  \
# 매장이름
# 강남YMCA점                      0                        0
# 강남구청역아이티웨딩점  37.51654171724045        127.0401601992311
# 강남논현학동점      37.51408005446769       127.02810578707652
# 강남대치점        37.50133876179308       127.05242928262568
# 강남도산점                        4  서울 강남구 도산대로37길 20 (신사동)
# ...                        ...                      ...
# 중랑묵동점        37.61335268312136        127.0775356804549
# 중랑역점                         0                        0
# 중화동점          37.5993838458016         127.079542626772
# 중화역점                        28       서울 중랑구 동일로 815, 1층
# 화랑대역점        37.61954020149987       127.08413727538176
#
#                                        주소
# 매장이름
# 강남YMCA점                        서울 강남구 논현동
# 강남구청역아이티웨딩점   서울 강남구 학동로 338 (논현동, 강남파라곤)
# 강남논현학동점           서울 강남구 논현로131길 28 (논현동)
# 강남대치점          서울 강남구 역삼로 415 (대치동, 성진빌딩)
# 강남도산점             서울 강남구 도산대로37길 20 (신사동)
# ...                                   ...
# 중랑묵동점        서울 중랑구 동일로 932 (묵동, 묵동자이아파트)
# 중랑역점                 서울 중랑구 망우로 198 (상봉동)
# 중화동점               서울 중랑구 동일로129길 1 (중화동)
# 중화역점                   서울 중랑구 동일로 815, 1층
# 화랑대역점         서울 중랑구 신내로25가길 2 (묵동, 현동학당)
#
# [660 rows x 3 columns]

# %% [markdown]
# #### lng 컬럼으로 결측값을 판단하자.

# %%
# 결측값을 판단하는 함수를 만듬.

def lng_outlier(var): # True 반환시 결측값이다.
    try:
        flag = int(float(var)) # 실수 -> 정수로 변환이 되는지, 문자열이면 예외문으로 빠짐
        # 문자열 -> 정수로 바로 변환이 되지않음(소수점있을때). 문자열 -> float -> int 해줘야 정수형 됨
        
    except:
        return True # 문자열인경우 True
    
    else:# 정수일 때
        if flag >= 126 and flag <= 128: # 126 ~ 128 사이일경우
            return False
        else:
            return True # 경도값이 이상값일 경우

# %%
# iterrows를 활용해 lng가 결측값이면 lat도 nan값으로 바꾸자.

for name, row in ED_stores.iterrows():
    if lng_outlier(row["lng"]) == True:
        ED_stores.loc[name,["lat","lng"]] = np.nan
    else:
        ED_stores.loc[name,"lat"] = float(row["lat"])
        ED_stores.loc[name,"lng"] = float(row["lng"])

ED_stores
# Out:
#                    lat         lng                            주소
# 매장이름
# 강남YMCA점            NaN         NaN                    서울 강남구 논현동
# 강남구청역아이티웨딩점  37.516542   127.04016   서울 강남구 학동로 338 (논현동, 강남파라곤)
# 강남논현학동점       37.51408  127.028106       서울 강남구 논현로131길 28 (논현동)
# 강남대치점        37.501339  127.052429    서울 강남구 역삼로 415 (대치동, 성진빌딩)
# 강남도산점              NaN         NaN       서울 강남구 도산대로37길 20 (신사동)
# ...                ...         ...                           ...
# 중랑묵동점        37.613353  127.077536  서울 중랑구 동일로 932 (묵동, 묵동자이아파트)
# 중랑역점               NaN         NaN          서울 중랑구 망우로 198 (상봉동)
# 중화동점         37.599384  127.079543        서울 중랑구 동일로129길 1 (중화동)
# 중화역점               NaN         NaN            서울 중랑구 동일로 815, 1층
# 화랑대역점         37.61954  127.084137   서울 중랑구 신내로25가길 2 (묵동, 현동학당)
#
# [660 rows x 3 columns]

# %% [markdown]
# #### lat / lng 둘 중 하나만 Nan값인 행이 있는지 데이터를 검증하자

# %%
# 검증 1.

for name, row in ED_stores.iterrows():
    if np.isnan(row["lng"]) == True: # lng가 Nan 값일때 lat은 Nan 값이 아니라면
        if np.isnan(row["lat"]) != True:
            print("둘 중 하나만 Nan값 입니다.")

print("지금 이 문장만 나온다면 검증 완료")
# Out:
# 지금 이 문장만 나온다면 검증 완료

# %%
# 검증 2. isnan 했을 때 둘다 True거나 둘다 False가 나와야한다.
# 두 결과가 같이 않으면 test 리스트에 담기 -> test가 빈 리스트면 검증 완료

test = [[idx,row["lat"],row["lng"]] for idx,row in ED_stores.iterrows() if np.isnan(row["lng"])!=np.isnan(row["lat"]) ]
test
# Out:
# []

# %%
ED_stores.to_csv("./Data/ED_stores.csv", encoding="euc-kr")

# %%
# 이디야 역삼더블루점은 폐업함 . 없애자
ED_stores = ED_stores[ED_stores.index != '역삼더블루점']
ED_stores

# %%
ED_stores
# Out:
#                    lat         lng                            주소
# 매장이름
# 강남YMCA점            NaN         NaN                    서울 강남구 논현동
# 강남구청역아이티웨딩점  37.516542   127.04016   서울 강남구 학동로 338 (논현동, 강남파라곤)
# 강남논현학동점       37.51408  127.028106       서울 강남구 논현로131길 28 (논현동)
# 강남대치점        37.501339  127.052429    서울 강남구 역삼로 415 (대치동, 성진빌딩)
# 강남도산점              NaN         NaN       서울 강남구 도산대로37길 20 (신사동)
# ...                ...         ...                           ...
# 중랑묵동점        37.613353  127.077536  서울 중랑구 동일로 932 (묵동, 묵동자이아파트)
# 중랑역점               NaN         NaN          서울 중랑구 망우로 198 (상봉동)
# 중화동점         37.599384  127.079543        서울 중랑구 동일로129길 1 (중화동)
# 중화역점               NaN         NaN            서울 중랑구 동일로 815, 1층
# 화랑대역점         37.61954  127.084137   서울 중랑구 신내로25가길 2 (묵동, 현동학당)
#
# [660 rows x 3 columns]

# %% [markdown]
# ## 2 - 6. 위도,경도 결측값 구글 지도로 다시 추출하기
# - 구글맵스 api로 해봤지만 그래도 결측값이 나왔다.
# - 구글지도에서는 위도경도를 추출할수 있으니 번거롭더라도 만들어서 데이터를 추출했다..

# %% [markdown]
# #### 결측값이 들어있는 데이터프레임을 하나 만들자

# %%
ED_outliers = ED_stores[ED_stores["lat"].isnull()]
ED_outliers
# Out:
#          lat  lng                           주소
# 매장이름
# 강남YMCA점  NaN  NaN                   서울 강남구 논현동
# 강남도산점    NaN  NaN      서울 강남구 도산대로37길 20 (신사동)
# 건설회관점    NaN  NaN         서울 강남구 언주로 711 (논현동)
# 도산사거리점   NaN  NaN                  서울 강남구 논현동
# 삼성동점     NaN  NaN      서울 강남구 테헤란로88길 10 (대치동)
# ...      ...  ...                          ...
# 서일중앙점    NaN  NaN  서울 중랑구 용마산로 394 (면목동, 해동검도)
# 신내동점     NaN  NaN        서울 중랑구 봉화산로 215 (신내동)
# 중랑교차로점   NaN  NaN         서울 중랑구 동일로 683 (면목동)
# 중랑역점     NaN  NaN         서울 중랑구 망우로 198 (상봉동)
# 중화역점     NaN  NaN           서울 중랑구 동일로 815, 1층
#
# [369 rows x 3 columns]

# %% [markdown]
# #### 구글 지도 웹드라이버로 켜기

# %%
# 셀레니움에서 웹드라이버 기능을 쓰겠다.
import time
from selenium.webdriver import ActionChains
from selenium.webdriver.common.by import By
from selenium import webdriver
from urllib import parse


# 웹드라이버 방법중 크롬을 쓰겠다. 크롬 드라이버를 넣어주겠다.
driver = webdriver.Chrome(executable_path="../driver/chromedriver.exe") # 경로, 권한 설정 잘해줘야
action = ActionChains(driver)
driver.get("https://www.google.co.kr/maps/?hl=ko")
#driver.get("https://www.google.co.kr/maps?hl=en")

time.sleep(3)

# 화면 최대 크기 설정 - 전체화면
driver.maximize_window()

# %% [markdown]
# #### 한 개 예시로 위도 경도 추출

# %%
# 검색창에 검색어 올리기

search_bar_tag = driver.find_element(By.CSS_SELECTOR,'#searchboxinput')
#search_bar_tag.send_keys("이디야 신내동점 서울 중랑구 봉화산로 215 (신내동)")
#search_bar_tag.send_keys("이디야 강남YMCA점 서울 강남구 논현동")
search_bar_tag.send_keys("이디야 서일중앙점 서울 중랑구 용마산로 394 (면목동, 해동검도)")

#search_bar_tag.send_keys(search_word)

# %%
# 검색결과 판별 함수

def search_fail():

    req = driver.page_source
    soup = BeautifulSoup(req, 'html.parser')

    flag = soup.select_one('#cell0x0 > span > span').text
    
    if 'Google 지도에 누락된 장소를 추가합니다.' == flag:
        return True
    
    else:
        return False

# %%
# 검색결과 판별해서 있으면 최상단 클릭하기 

if search_fail() == False:
    search_btn_tag = driver.find_element(By.CSS_SELECTOR,'#ydp1wd-haAclf > div:nth-child(1)')
    search_btn_tag.click()
    time.sleep(3)

else:
    search_bar_tag.clear()

# %%
# url 가져와서 디코드 변환하기

from urllib import parse

origin_url = driver.current_url
string_decoded = parse.unquote(origin_url)
print(string_decoded)
# Out:
# https://www.google.co.kr/maps/place/이디야서일중앙점/data=!3m1!4b1!4m6!3m5!1s0x357cbaf7ba4c98b5:0xac55d21f62188c50!8m2!3d37.5866117!4d127.0955358!16s/g/11grv9njwl?hl=ko&entry=ttu

# %%
# url 가져와서 디코드 변환하기

from urllib import parse

origin_url = driver.current_url
string_decoded = parse.unquote(origin_url)
print(string_decoded)
# Out:
# https://www.google.co.kr/maps/place/이디야+신내동점/data=!3m1!4b1!4m6!3m5!1s0x357cba38f5cd62e9:0x3d7e5d6bdefe6648!8m2!3d37.6076181!4d127.0965284!16s/g/11bx55kv04?hl=ko&entry=ttu

# %% [markdown]
# - url 에서 위도 경도 추출하기
#     - "!3d"위도"!4d"경도"!16s"

# %%
sample_lat = string_decoded.split("!3d")[1].split("!4d")[0]
sample_lng = string_decoded.split("!3d")[1].split("!4d")[1].split("!16s")[0]

print(sample_lat, sample_lng)
# Out:
# 37.5866117 127.0955358

# %%
# 검색결과 지우기 버튼 클릭

x_btn = driver.find_element(By.CSS_SELECTOR,'#searchbox > div.lSDxNd > button')
x_btn.click()

# %% [markdown]
# #### 위 작업을 반복문으로 위도 경도를 추출하자.

# %% [markdown]
# ##### 반복문 구조
# ```
# for x in ED_outliers:
#     1. 검색어 만들기
#     2. 검색창에 검색어 올리기
#     3. 검색결과에서 최상단 결과 누르기 or nan 추가하기
#     4. 검색결과의 url 주소 가져오기
#     5. url 주소에서 위도 경도 추출하기
#     6. 검색결과 지우기 버튼 클릭
# ```

# %%
# 검색어 만들기

search_word = "이디야 " + ED_outliers.index[0] + ED_outliers["주소"][n]
search_word
# Out:
# '이디야 강남YMCA점서울 강남구 언주로 711 (논현동)'

# %%
###  10개 반복 해보자.
from bs4 import BeautifulSoup
from urllib import parse


tmp_lat = []
tmp_lng = []

for n in notebook.tqdm(range(10)):
    
    # 1. 검색어 만들기
    search_word = "이디야 " + ED_outliers.index[n]
    
    
    # 2. 검색창에 검색어 올리기
    search_bar_tag = driver.find_element(By.CSS_SELECTOR,'#searchboxinput')
    search_bar_tag.send_keys(search_word)
    time.sleep(2)
    
    if search_fail() == True:# 이름으로만 검색이 안되면 주소까지 추가
        search_bar_tag.clear()
        search_word = "이디야 " + ED_outliers.index[n] + " " + ED_outliers["주소"][n]
        search_bar_tag.send_keys(search_word)
        time.sleep(2)

    
    # 3. 검색결과 판별해서 있으면 최상단 클릭하기 
    if search_fail() == False:
        search_btn_tag = driver.find_element(By.CSS_SELECTOR,'#ydp1wd-haAclf > div:nth-child(1)')
        search_btn_tag.click()
        time.sleep(2)

    else: # 검색결과가 없으면 nan 값 넣자.
        search_bar_tag.clear()
        tmp_lat.append(np.nan)
        tmp_lng.append(np.nan)
        continue
    
    # 4. 현재 url 가져와서 디코드 변환하기
    origin_url = driver.current_url
    string_decoded = parse.unquote(origin_url)
    print(f'{n} : {string_decoded}\n')
    
    
    # 5. url 주소에서 위도 경도 추출하기
    tmp_lat.append(string_decoded.split("!3d")[1].split("!4d")[0])
    tmp_lng.append(string_decoded.split("!3d")[1].split("!4d")[1].split("!16s")[0].split("!16z")[0])
    
    
    # 6. 검색결과 지우기 버튼 클릭
    x_btn = driver.find_element(By.CSS_SELECTOR,'#searchbox > div.lSDxNd > button')
    x_btn.click()
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# 0 : https://www.google.co.kr/maps/place/이디야+강남YMCA점/data=!3m1!4b1!4m6!3m5!1s0x357ca3f73eb049d9:0xccfb1085304c491a!8m2!3d37.5099018!4d127.0357061!16s/g/1pp2vgyxc?hl=ko&entry=ttu
#
# 1 : https://www.google.co.kr/maps/place/이디야+강남YMCA점/data=!3m1!4b1!4m6!3m5!1s0x357ca3f73eb049d9:0xccfb1085304c491a!8m2!3d37.5099018!4d127.0357061!16s/g/1pp2vgyxc?hl=ko&entry=ttu
#
# 2 : https://www.google.co.kr/maps/place/건설회관/data=!3m1!4b1!4m6!3m5!1s0x357ca3f35810cda5:0xfb7d154dbc56644e!8m2!3d37.5173236!4d127.034148!16s/g/1thr536w?hl=ko&entry=ttu
#
# 3 : https://www.google.co.kr/maps/place/이디야+도산사거리점/data=!3m1!4b1!4m6!3m5!1s0x357ca38b98bbffc1:0x35ef1e0b6b68b90c!8m2!3d37.5206233!4d127.0361133!16s/g/11c1vdwzbd?hl=ko&entry=ttu
#
# 4 : https://www.google.co.kr/maps/place/이디야커피+삼성동점/data=!3m1!4b1!4m6!3m5!1s0x357ca41507ed4389:0x3655e5ea58b0b4b4!8m2!3d37.5068213!4d127.0594077!16s/g/1v_sl5pd?hl=ko&entry=ttu
#
# 5 : https://www.google.co.kr/maps/place/이디야커피+삼성동점/data=!3m1!4b1!4m6!3m5!1s0x357ca41507ed4389:0x3655e5ea58b0b4b4!8m2!3d37.5068213!4d127.0594077!16s/g/1v_sl5pd?hl=ko&entry=ttu
#
# 6 : https://www.google.co.kr/maps/place/이디야커피+삼성동점/data=!3m1!4b1!4m6!3m5!1s0x357ca41507ed4389:0x3655e5ea58b0b4b4!8m2!3d37.5068213!4d127.0594077!16s/g/1v_sl5pd?hl=ko&entry=ttu
#
# 7 : https://www.google.co.kr/maps/place/이디야+압구정로데오역점/data=!3m1!4b1!4m6!3m5!1s0x357ca3879797f913:0xa85b7afe40b59d8!8m2!3d37.5275251!4d127.0388491!16s/g/11bw5v9pj3?hl=ko&entry=ttu
#
# 8 : https://www.google.co.kr/maps/place/이디야+압구정로데오역점/data=!3m1!4b1!4m6!3m5!1s0x357ca3879797f913:0xa85b7afe40b59d8!8m2!3d37.5275251!4d127.0388491!16s/g/11bw5v9pj3?hl=ko&entry=ttu
#
# 9 : https://www.google.co.kr/maps/place/이디야역삼점/data=!3m1!4b1!4m6!3m5!1s0x357ca156f1647177:0x6c6033c0b7c40638!8m2!3d37.49579!4d127.0405164!16s/g/1tjgmjlk?hl=ko&entry=ttu

# %%
tmp_lat
# Out:
# ['37.5099018',
#  '37.5222821',
#  '37.5173236',
#  '37.5206233',
#  '37.5068213',
#  '37.5103766',
#  '37.5096625',
#  '37.5275251',
#  nan,
#  '37.49579']

# %%
tmp_lng
# Out:
# ['127.0357061',
#  '127.0314799',
#  '127.034148',
#  '127.0361133',
#  '127.0594077',
#  '127.0649904',
#  '127.0426409',
#  '127.0388491',
#  nan,
#  '127.0405164']

# %% [markdown]
# #### 잘 나오니 이제 전체를 반복하자.

# %%
tmp_lat = []
tmp_lng = []

for name, row in notebook.tqdm(ED_outliers.iterrows()):
    
    # 1. 검색어 만들기
    search_word = "이디야 " + name + " " + row["주소"]
    

    # 2. 검색창에 검색어 올리기
    search_bar_tag = driver.find_element(By.CSS_SELECTOR,'#searchboxinput')
    search_bar_tag.send_keys(search_word)
    time.sleep(1)

    
    # 3. 검색결과 판별해서 있으면 최상단 클릭하기 
    if search_fail() == False:
        search_btn_tag = driver.find_element(By.CSS_SELECTOR,'#ydp1wd-haAclf > div:nth-child(1)')
        search_btn_tag.click()
        time.sleep(2)

    else: # 검색결과가 없으면 nan 값 넣자.
        search_bar_tag.clear()
        tmp_lat.append(np.nan)
        tmp_lng.append(np.nan)
        continue
    
    # 4. 현재 url 가져와서 디코드 변환하기
    origin_url = driver.current_url
    string_decoded = parse.unquote(origin_url)
    #print(f'{n} : {string_decoded}\n')
    
    
    # 5. url 주소에서 위도 경도 추출하기
    tmp_lat.append(string_decoded.split("!3d")[1].split("!4d")[0])
    tmp_lng.append(string_decoded.split("!3d")[1].split("!4d")[1].split("!16s")[0].split("!16z")[0])
    
    
    # 5. 검색결과 지우기 버튼 클릭
    x_btn = driver.find_element(By.CSS_SELECTOR,'#searchbox > div.lSDxNd > button')
    x_btn.click()
# Out:
# 0it [00:00, ?it/s]

# %%
tmp_lat
# Out:
# ['37.5099018',
#  '37.5099018',
#  '37.5173236',
#  '37.5173236',
#  '37.5068213',
#  '37.5068213',
#  '37.5096625',
#  '37.5275251',
#  nan,
#  '37.49579',
#  '37.49579',
#  '37.49579',
#  '37.5187933',
#  '37.4784579',
#  '37.6143905',
#  '37.6143905',
#  '37.6393061',
#  '37.6625002',
#  '37.6342771',
#  '37.6342771',
#  '37.5592805',
#  '127.1237425',
#  '126.8548809',
#  '126.8555982',
#  '126.8833201',
#  '126.8826805',
#  '126.8893535',
#  '126.8955092',
#  '126.897924',
#  '126.8870975',
#  '126.8670405',
#  '126.8242853',
#  nan,
#  '126.8903193',
#  '126.8437777',
#  '126.8435279',
#  nan,
#  '127.0309651',
#  '127.069321',
#  nan,
#  '127.0379383',
#  '127.0642249',
#  '127.0748317',
#  '127.0666931',
#  '127.0709119',
#  '127.0496055',
#  '127.0595782',
#  '127.0503144',
#  '127.0694723',
#  '127.0247986',
#  '127.0525842',
#  '127.048794',
#  '127.0373421',
#  '127.0421543',
#  '127.0301981',
#  '127.0357573',
#  '127.0578284',
#  '127.0621362',
#  '127.0552721',
#  '127.0196284',
#  '127.0156749',
#  '127.0167737',
#  '127.0384157',
#  '127.0302943',
#  '127.0347728',
#  '127.0309093',
#  '127.0662748',
#  '127.0259032',
#  '127.0415033',
#  '127.0337407',
#  '126.9750238',
#  '126.9751213',
#  '126.9703879',
#  '126.9719508',
#  '127.0059327',
#  '126.9646879',
#  '126.9691008',
#  '127.1031213',
#  '127.0983355',
#  '127.0885874',
#  '127.0926039',
#  '127.0881679',
#  '127.0905951',
#  '127.0873349',
#  '127.0955358',
#  '127.0965284',
#  '127.0798713',
#  '127.0748661',
#  nan]

# %%
driver.quit()

# %%
# 결측 데이터프레임에 추출한 정보 넣기
ED_outliers["lat"] = tmp_lat
ED_outliers["lng"] = tmp_lng
ED_outliers
# Out:
# C:\Users\Sam\AppData\Local\Temp\ipykernel_19828\2305434976.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ED_outliers["lat"] = tmp_lat
# C:\Users\Sam\AppData\Local\Temp\ipykernel_19828\2305434976.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ED_outliers["lng"] = tmp_lng
#                 lat          lng                           주소
# 매장이름
# 강남YMCA점  37.5099018  127.0357061                   서울 강남구 논현동
# 강남도산점    37.5099018  127.0357061      서울 강남구 도산대로37길 20 (신사동)
# 건설회관점    37.5173236   127.034148         서울 강남구 언주로 711 (논현동)
# 도산사거리점   37.5173236   127.034148                  서울 강남구 논현동
# 삼성동점     37.5068213  127.0594077      서울 강남구 테헤란로88길 10 (대치동)
# ...             ...          ...                          ...
# 서일중앙점    37.5866117  127.0955358  서울 중랑구 용마산로 394 (면목동, 해동검도)
# 신내동점     37.6076181  127.0965284        서울 중랑구 봉화산로 215 (신내동)
# 중랑교차로점   37.5913937  127.0798713         서울 중랑구 동일로 683 (면목동)
# 중랑역점      37.593212  127.0748661         서울 중랑구 망우로 198 (상봉동)
# 중화역점            NaN          NaN           서울 중랑구 동일로 815, 1층
#
# [369 rows x 3 columns]

# %%
ED_origin = ED_stores[ED_stores["lat"].isnull() == False]
ED_origin
# Out:
#                    lat         lng                              주소
# 매장이름
# 강남구청역아이티웨딩점  37.516542   127.04016     서울 강남구 학동로 338 (논현동, 강남파라곤)
# 강남논현학동점       37.51408  127.028106         서울 강남구 논현로131길 28 (논현동)
# 강남대치점        37.501339  127.052429      서울 강남구 역삼로 415 (대치동, 성진빌딩)
# 강남율현점        37.473549  127.107864   서울 강남구 밤고개로21길 8 (율현동, 세곡프라자)
# 강남자곡점        37.473606  127.103172  서울 강남구 자곡로 180 (자곡동, 강남유탑유블레스)
# ...                ...         ...                             ...
# 용마산역점        37.575435  127.085692          서울 중랑구 면목로 254-1 (면목동)
# 우림시장점        37.595311  127.099372           서울 중랑구 봉우재로 240 (망우동)
# 중랑묵동점        37.613353  127.077536    서울 중랑구 동일로 932 (묵동, 묵동자이아파트)
# 중화동점         37.599384  127.079543          서울 중랑구 동일로129길 1 (중화동)
# 화랑대역점         37.61954  127.084137     서울 중랑구 신내로25가길 2 (묵동, 현동학당)
#
# [291 rows x 3 columns]

# %%
ED_stores = pd.concat([ED_origin, ED_outliers], axis=0) # column bind

ED_stores
# Out:
#                     lat          lng                              주소
# 매장이름
# 강남구청역아이티웨딩점   37.516542    127.04016     서울 강남구 학동로 338 (논현동, 강남파라곤)
# 강남논현학동점        37.51408   127.028106         서울 강남구 논현로131길 28 (논현동)
# 강남대치점         37.501339   127.052429      서울 강남구 역삼로 415 (대치동, 성진빌딩)
# 강남율현점         37.473549   127.107864   서울 강남구 밤고개로21길 8 (율현동, 세곡프라자)
# 강남자곡점         37.473606   127.103172  서울 강남구 자곡로 180 (자곡동, 강남유탑유블레스)
# ...                 ...          ...                             ...
# 서일중앙점        37.5866117  127.0955358     서울 중랑구 용마산로 394 (면목동, 해동검도)
# 신내동점         37.6076181  127.0965284           서울 중랑구 봉화산로 215 (신내동)
# 중랑교차로점       37.5913937  127.0798713            서울 중랑구 동일로 683 (면목동)
# 중랑역점          37.593212  127.0748661            서울 중랑구 망우로 198 (상봉동)
# 중화역점                NaN          NaN              서울 중랑구 동일로 815, 1층
#
# [660 rows x 3 columns]

# %%
ED_nans = ED_stores[ED_stores["lat"].isnull()]
ED_nans
# Out:
#             lat  lng                                      주소
# 매장이름
# 역삼더블루점      NaN  NaN      서울 강남구 논현로63길 16 (역삼동, 역삼종합시장 더블루)
# 강서한강자이점     NaN  NaN                    서울 강서구 양천로 401 (가양동)
# 염창동점        NaN  NaN                    서울 강서구 양천로 689 (염창동)
# 관악구청점       NaN  NaN       서울 관악구 관악로 164 (봉천동, 대우디오슈페리움1단지)
# 건대로데오점      NaN  NaN                  서울 광진구 아차산로30길 8 (자양동)
# 건대스타시티점     NaN  NaN           서울 광진구 아차산로 272 (자양동, 더샵스타시티)
# 군자역점        NaN  NaN               서울 광진구 능동로 290 (능동, 삼일빌딩)
# 동서울터미널점     NaN  NaN                             서울 광진구 구의동
# 중곡역점        NaN  NaN                    서울 광진구 능동로 407 (중곡동)
# 금천롯데마트점     NaN  NaN     서울 금천구 시흥대로 291 (독산동, 금천롯데캐슬골드파크3차)
# 시흥유통센터점     NaN  NaN              서울 금천구 시흥대로 88 (시흥동, 오복빌딩)
# 상계역사거리점     NaN  NaN             서울 노원구 한글비석로 409 (상계동) 1~2층
# 중계브라운스톤점    NaN  NaN       서울 노원구 동일로203가길 29 (중계동, 브라운스톤중계)
# 중계중앙점       NaN  NaN                  서울 노원구 덕릉로73길 18 (중계동)
# 방학사거리점      NaN  NaN                    서울 도봉구 도봉로 677 (방학동)
# 보라매점        NaN  NaN     서울 동작구 보라매로5가길 16 (신대방동, 보라매아카데미타워)
# 사당점         NaN  NaN                    서울 동작구 동작대로 45 (사당동)
# 총신대점        NaN  NaN            서울 동작구 사당로16가길 96 (사당동) 1,2층
# 망원중앙점       NaN  NaN                   서울 마포구 월드컵로 147 (망원동)
# 오벨리스크점      NaN  NaN       서울 마포구 마포대로 33 (도화동, 마포 한화 오벨리스크)
# 가재울중앙점      NaN  NaN       서울 서대문구 가재울미래로 2 (남가좌동, DMC파크뷰자이)
# 명지전문대점      NaN  NaN                   서울 서대문구 가좌로 140 (홍은동)
# 무악재역점       NaN  NaN                            서울 서대문구 홍제동
# 신촌역점        NaN  NaN                 서울 서대문구 신촌로 87-20 (창천동)
# 양재하나로마트점    NaN  NaN           서울 서초구 청계산로 10 (양재동, 농협하나로클럽)
# 신정네거리역점     NaN  NaN                    서울 양천구 중앙로 282 (신정동)
# 도림점         NaN  NaN           서울 영등포구 도신로15길 40 (도림동, 도림빌딩)
# 양평동2가점      NaN  NaN   서울 영등포구 선유서로25길 19 (양평동2가, 오목교투웨니퍼스트)
# 영등포아크로타워점   NaN  NaN  서울 영등포구 국회대로54길 10 (영등포동7가, 아크로타워 스퀘어)
# 연신내통일로점     NaN  NaN                    서울 은평구 통일로 876 (불광동)
# 광화문트윈트리타워점  NaN  NaN            서울 종로구 율곡로 6 (중학동, 트윈 트리 빌딩)
# 배화여대점       NaN  NaN                  서울 종로구 필운대로1길 35 (필운동)
# 삼일빌딩점       NaN  NaN                 서울 종로구 삼일대로15길 13 (관철동)
# YTN점        NaN  NaN                 서울 중구 세종대로1길 11 (봉래동1가)
# 충무필동점       NaN  NaN                  서울 중구 퇴계로 218-5 (필동2가)
# 강동역점        NaN  NaN           서울 강동구 천호대로 1065 (천호동, 강동상떼빌)
# 천호로데오점      NaN  NaN                  서울 강동구 천호대로 1027 (천호동)
# 신도림메르디앙점    NaN  NaN    서울 구로구 신도림로 65 (신도림동, 신도림월드메르디앙오피스텔)
# 천왕이펜하우스점    NaN  NaN                     서울 구로구 천왕로 36 (천왕동)
# 용두동사거리점     NaN  NaN                    서울 동대문구 왕산로 68 (용두동)
# 중화역점        NaN  NaN                      서울 중랑구 동일로 815, 1층

# %%
# 1. 추출한 데이터 아웃라이어 리스트로 바꿔치기
# 2. 구글지도 추출데이터에서 Nan 값은 제외
# 3. 원본에서 nan값아닌 거 + 구글지도 검색한거 합치기
# 4. 저장

# %%
driver.quit()

# %% [markdown]
# ---

# %% [markdown]
# ## 2 - 5. 추출한 데이터 데이터프레임으로 만들기

# %%
ED_stores = pd.DataFrame(zip(ED_store_names, ED_store_lats, ED_store_lngs, ED_store_addrs))
ED_stores
# Out:
#                0                  1                        2  \
# 0        강남YMCA점                  0                        0
# 1    강남구청역아이티웨딩점  37.51654171724045        127.0401601992311
# 2        강남논현학동점  37.51408005446769       127.02810578707652
# 3          강남대치점  37.50133876179308       127.05242928262568
# 4          강남도산점                  4  서울 강남구 도산대로37길 20 (신사동)
# ..           ...                ...                      ...
# 655        중랑묵동점  37.61335268312136        127.0775356804549
# 656         중랑역점                  0                        0
# 657         중화동점   37.5993838458016         127.079542626772
# 658         중화역점                 28       서울 중랑구 동일로 815, 1층
# 659        화랑대역점  37.61954020149987       127.08413727538176
#
#                                 3
# 0                      서울 강남구 논현동
# 1     서울 강남구 학동로 338 (논현동, 강남파라곤)
# 2         서울 강남구 논현로131길 28 (논현동)
# 3      서울 강남구 역삼로 415 (대치동, 성진빌딩)
# 4         서울 강남구 도산대로37길 20 (신사동)
# ..                            ...
# 655  서울 중랑구 동일로 932 (묵동, 묵동자이아파트)
# 656          서울 중랑구 망우로 198 (상봉동)
# 657        서울 중랑구 동일로129길 1 (중화동)
# 658            서울 중랑구 동일로 815, 1층
# 659   서울 중랑구 신내로25가길 2 (묵동, 현동학당)
#
# [660 rows x 4 columns]

# %%
ED_stores.columns = ["매장이름", "lat", "lng", "주소"]

ED_stores.set_index('매장이름', inplace=True)
ED_stores
# Out:
#                            lat                      lng  \
# 매장이름
# 강남YMCA점                      0                        0
# 강남구청역아이티웨딩점  37.51654171724045        127.0401601992311
# 강남논현학동점      37.51408005446769       127.02810578707652
# 강남대치점        37.50133876179308       127.05242928262568
# 강남도산점                        4  서울 강남구 도산대로37길 20 (신사동)
# ...                        ...                      ...
# 중랑묵동점        37.61335268312136        127.0775356804549
# 중랑역점                         0                        0
# 중화동점          37.5993838458016         127.079542626772
# 중화역점                        28       서울 중랑구 동일로 815, 1층
# 화랑대역점        37.61954020149987       127.08413727538176
#
#                                        주소
# 매장이름
# 강남YMCA점                        서울 강남구 논현동
# 강남구청역아이티웨딩점   서울 강남구 학동로 338 (논현동, 강남파라곤)
# 강남논현학동점           서울 강남구 논현로131길 28 (논현동)
# 강남대치점          서울 강남구 역삼로 415 (대치동, 성진빌딩)
# 강남도산점             서울 강남구 도산대로37길 20 (신사동)
# ...                                   ...
# 중랑묵동점        서울 중랑구 동일로 932 (묵동, 묵동자이아파트)
# 중랑역점                 서울 중랑구 망우로 198 (상봉동)
# 중화동점               서울 중랑구 동일로129길 1 (중화동)
# 중화역점                   서울 중랑구 동일로 815, 1층
# 화랑대역점         서울 중랑구 신내로25가길 2 (묵동, 현동학당)
#
# [660 rows x 3 columns]

# %%
## 일단 웹드라이버는 사용이끝났으니 종료한다.
driver.quit()

# %% [markdown]
# ---

# %% [markdown]
# ## 2 - 6. 이디야 매장 위도, 경도 결측값 np.nan으로 초기화 하기

# %%
# lng 에서 결측값 판단하는 함수 만듬 : 문자열, 0, 127.~~ 이렇게 3개 있음
# 문자열 -> 정수로 바로 변환이 되지않음(소수점있을때). 문자열 -> float -> int 해줘야 정수형 됨

def lng_is_ok(var):
    try:
        flag = float(var)
        
    except:
        return False
    
    else:
        if flag >= 0:
            return True
        else:
            return False

        
for idx,row in ED_stores.iterrows():
    if lng_is_ok(row["lng"]) == False :
        ED_stores.loc[idx,["lat","lng"]] = np.nan

ED_stores
# Out:
#                            lat                 lng  \
# 매장이름
# 강남YMCA점                    NaN                 NaN
# 강남구청역아이티웨딩점  37.51654171724045   127.0401601992311
# 강남논현학동점      37.51408005446769  127.02810578707652
# 강남대치점        37.50133876179308  127.05242928262568
# 강남도산점                      NaN                 NaN
# ...                        ...                 ...
# 중랑묵동점        37.61335268312136   127.0775356804549
# 중랑역점                       NaN                 NaN
# 중화동점          37.5993838458016    127.079542626772
# 중화역점                       NaN                 NaN
# 화랑대역점        37.61954020149987  127.08413727538176
#
#                                        주소
# 매장이름
# 강남YMCA점                        서울 강남구 논현동
# 강남구청역아이티웨딩점   서울 강남구 학동로 338 (논현동, 강남파라곤)
# 강남논현학동점           서울 강남구 논현로131길 28 (논현동)
# 강남대치점          서울 강남구 역삼로 415 (대치동, 성진빌딩)
# 강남도산점             서울 강남구 도산대로37길 20 (신사동)
# ...                                   ...
# 중랑묵동점        서울 중랑구 동일로 932 (묵동, 묵동자이아파트)
# 중랑역점                 서울 중랑구 망우로 198 (상봉동)
# 중화동점               서울 중랑구 동일로129길 1 (중화동)
# 중화역점                   서울 중랑구 동일로 815, 1층
# 화랑대역점         서울 중랑구 신내로25가길 2 (묵동, 현동학당)
#
# [660 rows x 3 columns]

# %%
ED_stores["lng"] = ED_stores["lng"].astype("float")
ED_stores["lat"] = ED_stores["lat"].astype("float")

# %%
ED_stores["lng"].unique()
# Out:
# array([         nan, 127.0401602 , 127.02810579, 127.05242928,
#        127.10786369, 127.1031721 , 127.06742227, 127.07764131,
#        127.04304592, 127.06310437, 127.05329951, 127.04806967,
#        127.04819206, 127.10304411, 127.02145819, 127.02186508,
#        127.04399445, 127.03523957, 127.04811298, 127.042929  ,
#        127.03298154, 127.08160067, 127.05035288, 127.04914686,
#        127.03312379, 127.0336522 , 127.05611874, 127.01616395,
#        127.02260596, 127.03446065, 127.0310247 , 127.02970278,
#        127.02547799, 127.02875236, 127.03987378, 127.00561343,
#        127.01602468, 127.03562908, 127.08930305, 127.06724152,
#        127.0360344 , 127.08772353, 127.06197978, 127.08261339,
#        127.07788528, 127.01319601, 127.04374414, 127.01355695,
#        127.03810955, 127.02717853, 127.03470671, 127.03632065,
#        127.03874808, 127.04959434, 127.04966739, 127.05250451,
#        127.05139242, 127.03565327, 127.0024112 , 127.01711123,
#        127.00852441, 127.00399195, 127.0030194 , 127.00505326,
#        127.00568884, 127.01448804, 127.01625286, 127.03295892,
#        127.01938639, 127.03148744, 127.01212053, 127.04455087,
#        127.02955884, 127.04268857, 127.0622607 , 127.01589376,
#        127.02202493, 127.0456682 , 127.05246364, 127.05104362,
#        127.04561572, 127.11910673, 127.12496177, 127.1167319 ,
#        127.12087308, 127.13573191, 127.14434074, 127.11548124,
#        127.12670032, 127.12634066, 127.12093364, 127.12001625,
#        127.09579916, 127.08075331, 127.10445518, 127.10828473,
#        127.10584189, 127.10839491, 127.12526319, 127.11794613,
#        127.14280134, 127.12491386, 127.1135902 , 127.12583972,
#        127.13050371, 127.1319156 , 127.14207669, 127.13442428,
#        127.08585229, 127.09936151, 127.07918138, 127.02455282,
#        127.00805518, 127.02147608, 127.00182934, 127.00218469,
#        127.1725756 , 127.12985995, 127.14740203, 127.17410624,
#        127.16370019, 127.15518054, 127.14556505, 127.14578926,
#        127.17398322, 127.14074049, 127.12812621, 127.13472844,
#        127.12456936, 127.13480949, 127.05250416, 127.05111084,
#        127.05611323, 127.0618809 , 127.0406408 , 127.05481893,
#        127.02493296, 127.06125986, 127.07077591, 127.06144791,
#        127.06058696, 127.05749584, 127.00692431, 127.09418277,
#        127.0941588 , 127.09275658, 127.07689793, 127.08048931,
#        127.07968086, 127.08682607, 127.08319673, 127.083421  ,
#        127.08779016, 127.09776668, 127.09544804, 127.10675147,
#        127.0856924 , 127.09937185, 127.07753568, 127.07954263,
#        127.08413728])

# %% [markdown]
# ---

# %% [markdown]
# ## 2 - 7. 이디야 매장 위도 경도 다시 불러오기 - 한 개만
# - 위도, 경도를 사이트에서 불러오니 이상하다...
# - 구글맵스 api를 활용해서 다시 불러오자

# %%
import googlemaps
gmaps_key = "AIzaSyCkh2-SXnE37ekglf74zs4JPK-CwdE1KLo"
gmaps = googlemaps.Client(key=gmaps_key)

# %%
# 한 개 예시

#tmp = gmaps.geocode("이디야커피 " + ED_stores["매장이름"][0],language = "ko") # 테스트
tmp = gmaps.geocode("이디야 " + "강남도산점" + "서울 강남구 도산대로37길 20 (신사동)",language = "ko") # 테스트

tmp
# Out:
# [{'address_components': [{'long_name': '20',
#     'short_name': '20',
#     'types': ['premise']},
#    {'long_name': '도산대로37길',
#     'short_name': '도산대로37길',
#     'types': ['political', 'sublocality', 'sublocality_level_4']},
#    {'long_name': '강남구',
#     'short_name': '강남구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '06026', 'short_name': '06026', 'types': ['postal_code']}],
#   'formatted_address': '대한민국 서울특별시 강남구 도산대로37길 20',
#   'geometry': {'location': {'lat': 37.5222821, 'lng': 127.0314799},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.5236310802915,
#      'lng': 127.0328288802915},
#     'southwest': {'lat': 37.5209331197085, 'lng': 127.0301309197085}}},
#   'partial_match': True,
#   'place_id': 'ChIJ8ci0sY2jfDURW_W09JS4Rvg',
#   'plus_code': {'compound_code': 'G2CJ+WH 대한민국 서울특별시',
#    'global_code': '8Q99G2CJ+WH'},
#   'types': ['street_address']},
#  {'address_components': [{'long_name': '19',
#     'short_name': '19',
#     'types': ['premise']},
#    {'long_name': '도산대로37길',
#     'short_name': '도산대로37길',
#     'types': ['political', 'sublocality', 'sublocality_level_4']},
#    {'long_name': '강남구',
#     'short_name': '강남구',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': '서울특별시',
#     'short_name': '서울특별시',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '06024', 'short_name': '06024', 'types': ['postal_code']}],
#   'formatted_address': '대한민국 서울특별시 강남구 도산대로37길 19',
#   'geometry': {'location': {'lat': 37.522336, 'lng': 127.031173},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.52368498029149,
#      'lng': 127.0325219802915},
#     'southwest': {'lat': 37.52098701970849, 'lng': 127.0298240197085}}},
#   'partial_match': True,
#   'place_id': 'ChIJ6aLduo2jfDURWfd04VStQ-o',
#   'plus_code': {'compound_code': 'G2CJ+WF 대한민국 서울특별시',
#    'global_code': '8Q99G2CJ+WF'},
#   'types': ['cafe', 'establishment', 'food', 'point_of_interest']}]

# %%
# 'geometry': {'location': {'lat': 37.5099018, 'lng': 127.0357061} ==> 확인 해보니 맞다.
# 'geometry': {'location': {'lat': 37.5099018, 'lng': 127.0357061} 를 추출하자.

import folium

tmp_map = folium.Map(
    location = [37.5099018, 127.0357061],
    zoom_start = 15,
    #tiles = "Stamen Toner"
)

folium.Marker(
    location = [37.5099018, 127.0357061],
    #radius=rows["검거"]*50,

    #popup = rows["구분"] + " : " "%.2f"%rows["검거"], # 강남 : 0.75
    #tooltip = rows["구분"] + "경찰서 검거율",

    color = "#3186cc",
    fill = True,
    fill_color = "#3186cc"
).add_to(tmp_map)

tmp_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_309999cec553c52f1f07e21eb45fe040 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_309999cec553c52f1f07e21eb45fe040&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_309999cec553c52f1f07e21eb45fe040 = L.map(
#                 &quot;map_309999cec553c52f1f07e21eb45fe040&quot;,
#                 {
#                     center: [37.5099018, 127.0357061],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5aebe5e5c589dfca347ca7151a9bd82c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_309999cec553c52f1f07e21eb45fe040);
#
#
#             var marker_7432519693be9a2c6a7c6b6145ffdbf4 = L.marker(
#                 [37.5099018, 127.0357061],
#                 {&quot;color&quot;: &quot;#3186cc&quot;, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;}
#             ).addTo(map_309999cec553c52f1f07e21eb45fe040);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
print(tmp[0]["geometry"]["location"]["lat"])
print(tmp[0]["geometry"]["location"]["lng"])
# Out:
# 37.5222821
# 127.0314799

# %%
ED_stores.index[5]
# Out:
# '강남율현점'

# %%
# 이디야 커피매장 위도 경도 반복문으로 전체 추출

tmp_lat_one = []
tmp_lng_one = []

for n in notebook.tqdm(range(5)):
    tmp = gmaps.geocode("이디야 " + ED_stores.index[n], language = "ko")
    
    if tmp == []:
        tmp = gmaps.geocode("이디야 " + ED_stores.index[n] + " " + rows["주소"],language = "ko")
    
    if tmp != []:
        tmp_lat_one.append(tmp[0]["geometry"]["location"]["lat"])
        tmp_lng_one.append(tmp[0]["geometry"]["location"]["lng"])
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]

# %%
tmp_lat_one
# Out:
# [37.5164665, 37.514236, 37.4966645, 37.4966645, 37.4762779]

# %%
tmp_lng_one
# Out:
# [127.0404191, 127.031593, 127.0629804, 127.0629804, 127.1003704]

# %% [markdown]
# ---

# %% [markdown]
# ## 2 - 8. 이디야 매장 위도 경도 다시 불러오기 - 전체
#
# - 반복문 구조
#
# ```
# for in 이디야 매장 컬럼:
#
#     구글맵스에 검색하기
#     tmp_lat, tmp_lng에 위도, 경도 정보 넣기
# ```

# %%
ED_stores
# Out:
#                     lat          lng                              주소
# 매장이름
# 강남구청역아이티웨딩점   37.516542    127.04016     서울 강남구 학동로 338 (논현동, 강남파라곤)
# 강남논현학동점        37.51408   127.028106         서울 강남구 논현로131길 28 (논현동)
# 강남대치점         37.501339   127.052429      서울 강남구 역삼로 415 (대치동, 성진빌딩)
# 강남율현점         37.473549   127.107864   서울 강남구 밤고개로21길 8 (율현동, 세곡프라자)
# 강남자곡점         37.473606   127.103172  서울 강남구 자곡로 180 (자곡동, 강남유탑유블레스)
# ...                 ...          ...                             ...
# 서일중앙점        37.5866117  127.0955358     서울 중랑구 용마산로 394 (면목동, 해동검도)
# 신내동점         37.6076181  127.0965284           서울 중랑구 봉화산로 215 (신내동)
# 중랑교차로점       37.5913937  127.0798713            서울 중랑구 동일로 683 (면목동)
# 중랑역점          37.593212  127.0748661            서울 중랑구 망우로 198 (상봉동)
# 중화역점                NaN          NaN              서울 중랑구 동일로 815, 1층
#
# [660 rows x 3 columns]

# %%
# 이디야 커피매장 위도 경도 반복문으로 전체 추출

for idx,rows in notebook.tqdm(ED_stores.iterrows()):
    if np.isnan(float(rows["lng"])) == True:## 그냥 rows["lng"]는 자료형이 오브젝트형이다. 실수형으로 바꿔야한다.
        tmp = gmaps.geocode("이디야 " + idx,language = "ko")
    
        if tmp == []:
            tmp = gmaps.geocode("이디야 " + idx + " "+ rows["주소"],language = "ko")
    
        if tmp != []:
            ED_stores.loc[idx,"lat"] = tmp[0]["geometry"]["location"]["lat"]
            ED_stores.loc[idx,"lng"] = tmp[0]["geometry"]["location"]["lng"]
# Out:
# 0it [00:00, ?it/s]

# %%
ED_stores
# Out:
#                    lat         lng                            주소
# 매장이름
# 강남YMCA점      37.509902  127.035706                    서울 강남구 논현동
# 강남구청역아이티웨딩점  37.516542  127.040160   서울 강남구 학동로 338 (논현동, 강남파라곤)
# 강남논현학동점      37.514080  127.028106       서울 강남구 논현로131길 28 (논현동)
# 강남대치점        37.501339  127.052429    서울 강남구 역삼로 415 (대치동, 성진빌딩)
# 강남도산점        37.522282  127.031480       서울 강남구 도산대로37길 20 (신사동)
# ...                ...         ...                           ...
# 중랑묵동점        37.613353  127.077536  서울 중랑구 동일로 932 (묵동, 묵동자이아파트)
# 중랑역점         37.593285  127.074889          서울 중랑구 망우로 198 (상봉동)
# 중화동점         37.599384  127.079543        서울 중랑구 동일로129길 1 (중화동)
# 중화역점         37.603129  127.078889            서울 중랑구 동일로 815, 1층
# 화랑대역점        37.619540  127.084137   서울 중랑구 신내로25가길 2 (묵동, 현동학당)
#
# [660 rows x 3 columns]

# %%
for idx, rows in ED_stores.iterrows():
    if np.isnan(float(rows["lng"])) == True:
        print(pd.DataFrame(ED_stores.loc[[idx]]))
# Out:
#        lat  lng                    주소
# 매장이름
# 신림미성점  NaN  NaN  서울 관악구 난곡로 250 (신림동)
#          lat  lng           주소
# 매장이름
# 동서울터미널점  NaN  NaN  서울 광진구 구의동
#        lat  lng                     주소
# 매장이름
# 아차산역점  NaN  NaN  서울 광진구 천호대로 663 (구의동)
#            lat  lng                    주소
# 매장이름
# 도봉보건소사거리점  NaN  NaN  서울 도봉구 해등로 157 (쌍문동)
#       lat  lng                       주소
# 매장이름
# 방학역점  NaN  NaN  서울 도봉구 도봉로153길 15 (방학동)
#       lat  lng                   주소
# 매장이름
# 중앙대점  NaN  NaN  서울 동작구 흑석로 79 (흑석동)
#         lat  lng                     주소
# 매장이름
# 연희삼거리점  NaN  NaN  서울 서대문구 연희로 117 (연희동)
#        lat  lng                         주소
# 매장이름
# 동소문동점  NaN  NaN  서울 성북구 동소문로13길 5 (동소문동4가)
#         lat  lng                           주소
# 매장이름
# 영등포시장점  NaN  NaN  서울 영등포구 영등포로35길 19 (영등포동6가)

# %%
for idx, rows in ED_stores.iterrows():
    if np.isnan(float(rows["lat"])) == True:
        print(pd.DataFrame(ED_stores.loc[[idx]]))
# Out:
#        lat  lng                    주소
# 매장이름
# 신림미성점  NaN  NaN  서울 관악구 난곡로 250 (신림동)
#          lat  lng           주소
# 매장이름
# 동서울터미널점  NaN  NaN  서울 광진구 구의동
#        lat  lng                     주소
# 매장이름
# 아차산역점  NaN  NaN  서울 광진구 천호대로 663 (구의동)
#            lat  lng                    주소
# 매장이름
# 도봉보건소사거리점  NaN  NaN  서울 도봉구 해등로 157 (쌍문동)
#       lat  lng                       주소
# 매장이름
# 방학역점  NaN  NaN  서울 도봉구 도봉로153길 15 (방학동)
#       lat  lng                   주소
# 매장이름
# 중앙대점  NaN  NaN  서울 동작구 흑석로 79 (흑석동)
#         lat  lng                     주소
# 매장이름
# 연희삼거리점  NaN  NaN  서울 서대문구 연희로 117 (연희동)
#        lat  lng                         주소
# 매장이름
# 동소문동점  NaN  NaN  서울 성북구 동소문로13길 5 (동소문동4가)
#         lat  lng                           주소
# 매장이름
# 영등포시장점  NaN  NaN  서울 영등포구 영등포로35길 19 (영등포동6가)

# %% [markdown]
# ### 위의 데이터는 제거하고 진행하자..........

# %%
ED_stores = ED_stores[np.isnan(ED_stores["lng"]) == False]
ED_stores
# Out:
#                    lat         lng                            주소
# 매장이름
# 강남YMCA점      37.509902  127.035706                    서울 강남구 논현동
# 강남구청역아이티웨딩점  37.516542  127.040160   서울 강남구 학동로 338 (논현동, 강남파라곤)
# 강남논현학동점      37.514080  127.028106       서울 강남구 논현로131길 28 (논현동)
# 강남대치점        37.501339  127.052429    서울 강남구 역삼로 415 (대치동, 성진빌딩)
# 강남도산점        37.522282  127.031480       서울 강남구 도산대로37길 20 (신사동)
# ...                ...         ...                           ...
# 중랑묵동점        37.613353  127.077536  서울 중랑구 동일로 932 (묵동, 묵동자이아파트)
# 중랑역점         37.593285  127.074889          서울 중랑구 망우로 198 (상봉동)
# 중화동점         37.599384  127.079543        서울 중랑구 동일로129길 1 (중화동)
# 중화역점         37.603129  127.078889            서울 중랑구 동일로 815, 1층
# 화랑대역점        37.619540  127.084137   서울 중랑구 신내로25가길 2 (묵동, 현동학당)
#
# [651 rows x 3 columns]

# %%
for idx, rows in ED_stores.iterrows():
    if np.isnan(float(rows["lng"])) == True:
        print(pd.DataFrame(ED_stores.loc[[idx]]))

        #출력안되서 없음을 확인

# %%
for idx, rows in ED_stores.iterrows():
    if np.isnan(float(rows["lat"])) == True:
        print(pd.DataFrame(ED_stores.loc[[idx]]))

        #출력안되서 없음을 확인

# %%
ED_stores
# Out:
#                    lat         lng                            주소
# 매장이름
# 강남YMCA점      37.509902  127.035706                    서울 강남구 논현동
# 강남구청역아이티웨딩점  37.516542  127.040160   서울 강남구 학동로 338 (논현동, 강남파라곤)
# 강남논현학동점      37.514080  127.028106       서울 강남구 논현로131길 28 (논현동)
# 강남대치점        37.501339  127.052429    서울 강남구 역삼로 415 (대치동, 성진빌딩)
# 강남도산점        37.522282  127.031480       서울 강남구 도산대로37길 20 (신사동)
# ...                ...         ...                           ...
# 중랑묵동점        37.613353  127.077536  서울 중랑구 동일로 932 (묵동, 묵동자이아파트)
# 중랑역점         37.593285  127.074889          서울 중랑구 망우로 198 (상봉동)
# 중화동점         37.599384  127.079543        서울 중랑구 동일로129길 1 (중화동)
# 중화역점         37.603129  127.078889            서울 중랑구 동일로 815, 1층
# 화랑대역점        37.619540  127.084137   서울 중랑구 신내로25가길 2 (묵동, 현동학당)
#
# [651 rows x 3 columns]

# %%
### 구 컬럼 추가
ED_stores["구"] = [items.split()[1] for items in ED_stores["주소"]]

ED_stores
# Out:
# C:\Users\Sam\AppData\Local\Temp\ipykernel_15664\2921317657.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ED_stores["구"] = [items.split()[1] for items in ED_stores["주소"]]
#                    lat         lng                            주소    구
# 매장이름
# 강남YMCA점      37.509902  127.035706                    서울 강남구 논현동  강남구
# 강남구청역아이티웨딩점  37.516542  127.040160   서울 강남구 학동로 338 (논현동, 강남파라곤)  강남구
# 강남논현학동점      37.514080  127.028106       서울 강남구 논현로131길 28 (논현동)  강남구
# 강남대치점        37.501339  127.052429    서울 강남구 역삼로 415 (대치동, 성진빌딩)  강남구
# 강남도산점        37.522282  127.031480       서울 강남구 도산대로37길 20 (신사동)  강남구
# ...                ...         ...                           ...  ...
# 중랑묵동점        37.613353  127.077536  서울 중랑구 동일로 932 (묵동, 묵동자이아파트)  중랑구
# 중랑역점         37.593285  127.074889          서울 중랑구 망우로 198 (상봉동)  중랑구
# 중화동점         37.599384  127.079543        서울 중랑구 동일로129길 1 (중화동)  중랑구
# 중화역점         37.603129  127.078889            서울 중랑구 동일로 815, 1층  중랑구
# 화랑대역점        37.619540  127.084137   서울 중랑구 신내로25가길 2 (묵동, 현동학당)  중랑구
#
# [651 rows x 4 columns]

# %% [markdown]
# ---

# %% [markdown]
# ## 2 - 9. 이디야 매장 목록 CSV로 저장하기

# %%
ED_stores.to_csv("./Data/ED_stores.csv", encoding="euc-kr")

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# # 3. 결과 데이터 분석하기

# %%
# 위도 경도 거리를 계산해주는 모듈
# !pip install haversine
# Out:
# Collecting haversine
#   Downloading haversine-2.8.0-py2.py3-none-any.whl (7.7 kB)
# Installing collected packages: haversine
# Successfully installed haversine-2.8.0

# %%
from haversine import haversine
import pandas as pd

# %%
# 강남구 예로 들기

# %%
## 스타벅스 데이터 불러오기
Starbucks_stores = pd.read_csv("./Data/SB_stores.csv",encoding="euc-kr", index_col = 0)
Starbucks_stores.set_index("매장이름",inplace=True)
Starbucks_stores
# Out:
#                lat         lng                                  주소    구
# 매장이름
# 역삼아레나빌딩  37.501087  127.043069             서울특별시 강남구 언주로 425 (역삼동)  강남구
# 논현역사거리   37.510178  127.022223            서울특별시 강남구 강남대로 538 (논현동)  강남구
# 신사역성일빌딩  37.513931  127.020606            서울특별시 강남구 강남대로 584 (논현동)  강남구
# 국기원사거리   37.499517  127.031495            서울특별시 강남구 테헤란로 125 (역삼동)  강남구
# 대치재경빌딩R  37.494668  127.062583          서울특별시 강남구 남부순환로 2947 (대치동)  강남구
# ...            ...         ...                                 ...  ...
# 사가정역     37.579594  127.087966         서울특별시 중랑구 면목로 3101522-3232)  중랑구
# 상봉역      37.596890  127.086470             서울특별시 중랑구 망우로 307 (상봉동)  중랑구
# 묵동       37.615368  127.076633  서울특별시 중랑구 동일로 952 (묵동, 로프트원 태릉입구역)  중랑구
# 양원역      37.606654  127.106360           서울특별시 중랑구 양원역로10길 3 (망우동)  중랑구
# 중화역      37.601709  127.078411        서울특별시 중랑구 봉화산로 35 1522-3232)  중랑구
#
# [601 rows x 4 columns]

# %%
## 이디야 데이터 불러오기
Ediya_stores = pd.read_csv("./Data/ED_stores.csv",encoding="euc-kr", index_col = 0)
Ediya_stores
# Out:
#                    lat         lng                            주소    구
# 매장이름
# 강남YMCA점      37.509902  127.035706                    서울 강남구 논현동  강남구
# 강남구청역아이티웨딩점  37.516542  127.040160   서울 강남구 학동로 338 (논현동, 강남파라곤)  강남구
# 강남논현학동점      37.514080  127.028106       서울 강남구 논현로131길 28 (논현동)  강남구
# 강남대치점        37.501339  127.052429    서울 강남구 역삼로 415 (대치동, 성진빌딩)  강남구
# 강남도산점        37.522282  127.031480       서울 강남구 도산대로37길 20 (신사동)  강남구
# ...                ...         ...                           ...  ...
# 중랑묵동점        37.613353  127.077536  서울 중랑구 동일로 932 (묵동, 묵동자이아파트)  중랑구
# 중랑역점         37.593285  127.074889          서울 중랑구 망우로 198 (상봉동)  중랑구
# 중화동점         37.599384  127.079543        서울 중랑구 동일로129길 1 (중화동)  중랑구
# 중화역점         37.603129  127.078889            서울 중랑구 동일로 815, 1층  중랑구
# 화랑대역점        37.619540  127.084137   서울 중랑구 신내로25가길 2 (묵동, 현동학당)  중랑구
#
# [651 rows x 4 columns]

# %%
SB_Gangnam = Starbucks_stores[Starbucks_stores["구"] == "강남구"]
SB_Gangnam
# Out:
#                 lat         lng                          주소    구
# 매장이름
# 역삼아레나빌딩   37.501087  127.043069     서울특별시 강남구 언주로 425 (역삼동)  강남구
# 논현역사거리    37.510178  127.022223    서울특별시 강남구 강남대로 538 (논현동)  강남구
# 신사역성일빌딩   37.513931  127.020606    서울특별시 강남구 강남대로 584 (논현동)  강남구
# 국기원사거리    37.499517  127.031495    서울특별시 강남구 테헤란로 125 (역삼동)  강남구
# 대치재경빌딩R   37.494668  127.062583  서울특별시 강남구 남부순환로 2947 (대치동)  강남구
# ...             ...         ...                         ...  ...
# 삼성역       37.509207  127.065609    서울특별시 강남구 테헤란로 620 (대치동)  강남구
# 역삼월드점        37.498448  127.048113       서울 강남구 역삼로52길 14 (역삼동, 도곡프라자)  강남구
# 역삼점          37.495841  127.040544              서울 강남구 논현로72길 13 (역삼동)  강남구
# 역삼중앙점        37.500315  127.042929               서울 강남구 언주로81길 8 (역삼동)  강남구
# 역삼충현점        37.503788  127.036330               서울 강남구 논현로98길 7 (역삼동)  강남구
# 역삼플래티넘점      37.495332  127.030372    서울 강남구 테헤란로4길 46 (역삼동, 쌍용플래티넘밸류)  강남구
# 을지병원사거리점     37.518793  127.028775              서울 강남구 도산대로30길 7 (논현동)  강남구
# 이디야커피랩       37.510473  127.032982         서울 강남구 논현로 636 (논현동, 이디야빌딩)  강남구
# 일원동점         37.490402  127.081601             서울 강남구 양재대로27길 20 (일원동)  강남구
# 청담사거리점       37.524856  127.050353               서울 강남구 도산대로 521 (청담동)  강남구
# 청담역점         37.520064  127.049147        서울 강남구 삼성로 721 (청담동, 룩희 819)  강남구
# 포이사거리점       37.477076  127.045604                서울 강남구 개포로 218 (개포동)  강남구
# 학동역점         37.514994  127.033124          서울 강남구 학동로 219 (논현동, 국제빌딩)  강남구
# 학동제마점        37.513117  127.033652              서울 강남구 학동로34길 22 (논현동)  강남구
# 한티역점         37.497949  127.056119               서울 강남구 도곡로69길 8 (대치동)  강남구

# %%
# 강남구 시각화 [34.4967, 127.0708]
import folium

Gangnam_map = folium.Map(location= [37.4967, 127.0708],zoom_start=13)
Gangnam_map


for idx,rows in SB_Gangnam.iterrows():
    
    # 위치값
    lat, lng = rows["lat"], rows["lng"]
    
    # 마커 찍기
    folium.Marker(
        location = [lat, lng],
        popup = idx,
        #tooltip = rows.분류,
        icon = folium.Icon(
            icon = "coffee",
            prefix= "fa",
            color = "green"
            #icon_color = "darkred" if rows.세대수 >= 199 else "darkblue",
        )
    ).add_to(Gangnam_map)

    
for idx,rows in ED_Gangnam.iterrows():
    
    # 위치값
    lat, lng = rows["lat"], rows["lng"]
    
    # 마커 찍기
    folium.Marker(
        location = [lat, lng],
        popup = idx,
        #tooltip = rows.분류,
        icon = folium.Icon(
            icon = "coffee",
            prefix= "fa",
            color = "blue"
            #icon_color = "darkred" if rows.세대수 >= 199 else "darkblue",
        )
    ).add_to(Gangnam_map)    

Gangnam_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_190d5f92b20933ab8c97b8d6177e2704 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_190d5f92b20933ab8c97b8d6177e2704&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_190d5f92b20933ab8c97b8d6177e2704 = L.map(
#                 &quot;map_190d5f92b20933ab8c97b8d6177e2704&quot;,
#                 {
#                     center: [37.4967, 127.0708],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e89a363b66b5f7901d6d93fd9e1e6c40 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_190d5f92b20933ab8c97b8d6177e2704);
#
#
#             var marker_13f01e3fc4e4f9b83940ffc3ebfa6653 = L.marker(
#                 [37.501087, 127.043069],
#                 {}
#             ).addTo(map_190d5f92b20933ab8c97b8d6177e2704);
#
#
#             var icon_7879c618c03e9443f201c044d0dfa113 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;coffee&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_13f01e3fc4e4f9b83940ffc3ebfa6653.setIcon(icon_7879c618c03e9443f201c044d0dfa113);
#
#
#         var popup_e4d50ff3660d8777001a7bca1fe201d4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3662b13eb67ffa1ded4a461dd3b37f3c = $(`&lt;div id=&quot;html_3662b13eb67ffa1ded4a461dd3b37f3c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;역삼아레나빌딩&lt;/div&gt;`)[0];
#                 popup_e4d50ff3660d8777001a7bca1fe201d4.setContent(html_3662b13eb67ffa1ded4a461dd3b37f3c);
#
#
#
#         marker_13f01e3fc4e4f9b83940ffc3ebfa6653.bindPopup(popup_e4d50ff3660d8777001a7bca1fe201d4)
#         ;
#
#
#
#
#             var marker_2e4ff90e066134d86d5de22da112c1c2 = L.marker(
#                 [37.510178, 127.022223],
#                 {}
#             ).addTo(map_190d5f92b20933ab8c97b8d6177e2704);
#
#
#             var icon_5ca8b5ea1d4197ca9bd10dad0fb01a82 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;coffee&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_2e4ff90e066134d86d5de22da112c1c2.setIcon(icon_5ca8b5ea1d4197ca9bd10dad0fb01a82);
#
#
#         var popup_2163a85672a4fbb08ae2a31f30a516a1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d0ce21724821ccb09896d4bb168c2cd5 = $(`&lt;div id=&quot;html_d0ce21724821ccb09896d4bb168c2cd5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;논현역사거리&lt;/div&gt;`)[0];
#                 popup_2163a85672a4fbb08ae2a31f30a516a1.setContent(html_d0ce21724821ccb09896d4bb168c2cd5);
#
#
#
#         marker_2e4ff90e066134d86d5de22da112c1c2.bindPopup(popup_2163a85672a4fbb08ae2a31f30a516a1)
#         ;
#
#
#
#
#             var marker_58cab2121062219006845041954eb4d2 = L.marker(
#                 [37.5139309, 127.0206057],
#                 {}
#             ).addTo(map_190d5f92b20933ab8c97b8d6177e2704);
#
#
#             var icon_a035a1574fdb29dbce28a10e73099647 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;coffee&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_58cab2121062219006845041954eb4d2.setIcon(icon_a035a1574fdb29dbce28a10e73099647);
#
#
#         var popup_a8caacef82ca6e7d73e12c5ce05f46e2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5e92def26d6d0cefcb224c93a2a8da6d = $(`&lt;div id=&quot;html_5e92def26d6d0cefcb224c93a2a8da6d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;신사역성일빌딩&lt;/div&gt;`)[0];
#                 popup_a8caacef82ca6e7d73e12c5ce05f46e2.setContent(html_5e92def26d6d0cefcb224c93a2a8da6d);
#
#
#
#         marker_58cab2121062219006845041954eb4d2.bindPopup(popup_a8caacef82ca6e7d73e12c5ce05f46e2)
#         ;
#
#
#
#
#             var marker_9b8fada8f9d1d0f7948fa2f7b2ab1873 = L.marker(
#                 [37.499517, 127.031495],
#                 {}
#             ).addTo(map_190d5f92b20933ab8c97b8d6177e2704);
#
#
#             var icon_ef42fd7ac0c3719e3f5e1b035ab2b4b2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;coffee&quot;, &quot;iconColor&quot;: &quot;wh

# %%
# 서울 전체로 해보자 시각화 [37.5515, 127.9891] => 너무 렉이 심하니까 구 별로 보자
import folium

seoul_map = folium.Map(location= [37.5515, 126.9891],zoom_start=13)


for idx,rows in Starbucks_stores.iterrows():
    
    # 위치값
    lat, lng = rows["lat"], rows["lng"]
    
    # 마커 찍기
    folium.Marker(
        location = [lat, lng],
        popup = idx,
        #tooltip = rows.분류,
        icon = folium.Icon(
            icon = "coffee",
            prefix= "fa",
            color = "green"
            #icon_color = "darkred" if rows.세대수 >= 199 else "darkblue",
        )
    ).add_to(seoul_map)

    
for idx,rows in Ediya_stores.iterrows():
    
    # 위치값
    lat, lng = rows["lat"], rows["lng"]
    
    # 마커 찍기
    folium.Marker(
        location = [lat, lng],
        popup = idx,
        #tooltip = rows.분류,
        icon = folium.Icon(
            icon = "coffee",
            prefix= "fa",
            color = "blue"
            #icon_color = "darkred" if rows.세대수 >= 199 else "darkblue",
        )
    ).add_to(seoul_map)    

seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_46d4405651e3937c2dd29f405016b4df {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_46d4405651e3937c2dd29f405016b4df&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_46d4405651e3937c2dd29f405016b4df = L.map(
#                 &quot;map_46d4405651e3937c2dd29f405016b4df&quot;,
#                 {
#                     center: [37.5515, 126.9891],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_222ba01fd841c1f4337f04f0a7680486 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_46d4405651e3937c2dd29f405016b4df);
#
#
#             var marker_99529de33a41227484b94cf447faa156 = L.marker(
#                 [37.501087, 127.043069],
#                 {}
#             ).addTo(map_46d4405651e3937c2dd29f405016b4df);
#
#
#             var icon_1b8c37b06619b2356fbcd1716353b4b2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;coffee&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_99529de33a41227484b94cf447faa156.setIcon(icon_1b8c37b06619b2356fbcd1716353b4b2);
#
#
#         var popup_3a0a49a2918cb86c5e5dfe7cdb856269 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_adeef942a82cb2c9d2208c4dcb0ec1ea = $(`&lt;div id=&quot;html_adeef942a82cb2c9d2208c4dcb0ec1ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;역삼아레나빌딩&lt;/div&gt;`)[0];
#                 popup_3a0a49a2918cb86c5e5dfe7cdb856269.setContent(html_adeef942a82cb2c9d2208c4dcb0ec1ea);
#
#
#
#         marker_99529de33a41227484b94cf447faa156.bindPopup(popup_3a0a49a2918cb86c5e5dfe7cdb856269)
#         ;
#
#
#
#
#             var marker_9971cc3e5b219b1282190ce0c1e9d66b = L.marker(
#                 [37.510178, 127.022223],
#                 {}
#             ).addTo(map_46d4405651e3937c2dd29f405016b4df);
#
#
#             var icon_0ae0a1893c9d528e1d19db0698b9c483 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;coffee&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_9971cc3e5b219b1282190ce0c1e9d66b.setIcon(icon_0ae0a1893c9d528e1d19db0698b9c483);
#
#
#         var popup_f5ee255fe39c330194d98c659a73a1c9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_da35e2f3cb2ad730cd345e92a8a62b33 = $(`&lt;div id=&quot;html_da35e2f3cb2ad730cd345e92a8a62b33&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;논현역사거리&lt;/div&gt;`)[0];
#                 popup_f5ee255fe39c330194d98c659a73a1c9.setContent(html_da35e2f3cb2ad730cd345e92a8a62b33);
#
#
#
#         marker_9971cc3e5b219b1282190ce0c1e9d66b.bindPopup(popup_f5ee255fe39c330194d98c659a73a1c9)
#         ;
#
#
#
#
#             var marker_2d9af56f478db434634a119f1afa72ac = L.marker(
#                 [37.5139309, 127.0206057],
#                 {}
#             ).addTo(map_46d4405651e3937c2dd29f405016b4df);
#
#
#             var icon_ff4083ae1ccc67fb7dae675a5cb367f5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;coffee&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_2d9af56f478db434634a119f1afa72ac.setIcon(icon_ff4083ae1ccc67fb7dae675a5cb367f5);
#
#
#         var popup_0a929d911d71400ef9c3b6ace0bd03cc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d04875809db3ecf8f59d06b183dcb136 = $(`&lt;div id=&quot;html_d04875809db3ecf8f59d06b183dcb136&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;신사역성일빌딩&lt;/div&gt;`)[0];
#                 popup_0a929d911d71400ef9c3b6ace0bd03cc.setContent(html_d04875809db3ecf8f59d06b183dcb136);
#
#
#
#         marker_2d9af56f478db434634a119f1afa72ac.bindPopup(popup_0a929d911d71400ef9c3b6ace0bd03cc)
#         ;
#
#
#
#
#             var marker_1ff8bb5fa244dafee671c2fe6943c773 = L.marker(
#                 [37.499517, 127.031495],
#                 {}
#             ).addTo(map_46d4405651e3937c2dd29f405016b4df);
#
#
#             var icon_06dc6f2ed2cf106aa7979029dbf339cb = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;coffee&quot;, &quot;iconColor&quot;: &quot;wh
